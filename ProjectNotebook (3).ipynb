# %% [markdown]
# ## INDIAN START UPS ECOSYSTEM ANALYSIS IN 2018-2021

# %% [markdown]
# ## 1. BUSINESS UNDERSTANDING
#
# Our Team, Santa Fe is trying to venture into the Indian Startup Ecosystem.  With numerous of successful enterprises earning the coveted "unicorn" label, India has become a favored investment destination. Our team will make an effort to respond by analyzing the data from 2018-2021 in order to focus our search for the best course of action for investment as a young organization.

# %% [markdown]
# ## 2. DATA COLLECTION AND DATA PREPARATION
#    ## 2.1 DATA COLLECTION
#
# Provided with 4 datasets - the first 2 are to be imported from LP1 database, one exits in onedrive and the other is found in Github Repository.

# %%
# DATA IMPORTS IN THE LP1 DATABASE
# 1. Install pyodbc and python-dotenv
# %pip install pyodbc  
# %pip install python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pyodbc in c:\users\precious\anaconda\lib\site-packages (4.0.34)
#
# Requirement already satisfied: python-dotenv in c:\users\precious\anaconda\lib\site-packages (1.0.0)Note: you may need to restart the kernel to use updated packages.

# %%
## Import all the necessary packages

import pyodbc                    #just installed with pip
from dotenv import dotenv_values #import the dotenv_values function from the dotenv package
import pandas as pd
import numpy as np
import warnings 
import matplotlib.pyplot as plt
import re
import matplotlib.ticker as ticker

# Set the display format for floats
pd.options.display.float_format = '{:.2f}'.format

warnings.filterwarnings('ignore')

# %%
# Load environment variables from .env file into a dictionary
environment_variables = dotenv_values('.env')


# Get the values for the credentials you set in the '.env' file
database = environment_variables.get("DATABASE")
server = environment_variables.get("SERVER")
username = environment_variables.get("USERNAME")
password = environment_variables.get("PASSWORD")


connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}"

# %%
# Use the connect method of the pyodbc library and pass in the connection string.
# This will connect to the server and might take a few seconds to be complete. 
# Check your internet connection if it takes more time than necessary

connection = pyodbc.connect(connection_string)

# %%
# Now the sql query to get the data is what what you see below. 
# Note that you will not have permissions to insert delete or update this database table. 

query = "Select * from dbo.LP1_startup_funding2020"
data20 = pd.read_sql(query, connection)
data20.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin  2019.00     Chennai            AgriTech
# 1      Krayonnz  2019.00   Bangalore              EdTech
# 2  PadCare Labs  2018.00        Pune  Hygiene management
# 3         NCOME  2020.00   New Delhi              Escrow
# 4    Gramophone  2016.00      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount     Stage column10
# 0                      Angel investors 200000.00      None     None
# 1                      GSF Accelerator 100000.00  Pre-seed     None
# 2                       Venture Center       NaN  Pre-seed     None
# 3  Venture Catalysts, PointOne Capital 400000.00      None     None
# 4  Siana Capital Management, Info Edge 340000.00      None     None

# %%
data20.columns
# Out:
# Index(['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'column10'],
#       dtype='object')

# %%
# Importing the Table 2.
query = "Select * from dbo.LP1_startup_funding2021"
data21 = pd.read_sql(query, connection)
data21.head()
# Out:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics  2019.00   Bangalore      AI startup
# 1          upGrad  2015.00      Mumbai          EdTech
# 2     Lead School  2012.00      Mumbai          EdTech
# 3         Bizongo  2015.00      Mumbai  B2B E-commerce
# 4        FypMoney  2021.00    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor        Amount         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
data21.columns
# Out:
# Index(['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage'],
#       dtype='object')

# %%
# Second Data from one Drive
data19 = pd.read_csv('startup_funding2019.csv')

data19.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru  2014.00      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane  2014.00     Chennai  Interior design
# 4        Nu Genes  2004.00   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
data19.columns
# Out:
# Index(['Company/Brand', 'Founded', 'HeadQuarter', 'Sector', 'What it does',
#        'Founders', 'Investor', 'Amount($)', 'Stage'],
#       dtype='object')

# %%
# 3rd Data Set from git hub respository
data18 = pd.read_csv('startup_funding2018.csv')

data18.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
data18.columns
# Out:
# Index(['Company Name', 'Industry', 'Round/Series', 'Amount', 'Location',
#        'About Company'],
#       dtype='object')

# %% [markdown]
# ## HYPOTHESIS FORMULATION

# %% [markdown]
# Null Hypotheis - The tech sector doesnt have highest Sucess rate of being funded.
#
# Alternative Hypothesis - The tech Sector has highest success rate of being funded  and investors should venture in the Tech Industry in Indian.

# %% [markdown]
# QUESTIONS

# %% [markdown]
#  The following questions were asked to assist in the data analysis process:
#
# 1. Which company has the highest funding?
# 2. Which sector has the highest funding?
# 3. What is total amount of funding received and for each year?
# 4. Which is location recieved most funding?
# 5. At what stage do start up recieve most funding?

# %% [markdown]
#    ## 2.2 DATA CLEANING

# %% [markdown]
# ### 2.2.1. Cleaning the 2018 dataset

# %%
# Cleaning the 2019 dataset
data18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %% [markdown]
# ### I. Dropping the columns not needed for analysis

# %%
# Dropping the 'About' columns since it is not present in the other datasets
data18 = data18.drop('About Company', axis=1)
data18.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India

# %% [markdown]
# ### II. Check for duplicates in the dataset

# %%
# Check for duplicates
duplicates = data18.duplicated(keep=False)

# Returns the total number of duplicates
duplicates_count = duplicates.value_counts()
duplicates_count
# Out:
# False    524
# True       2
# dtype: int64

# %%
# Identifying the duplicate rows
duplicates = data18[data18.duplicated(keep=False)]
duplicates
# Out:
#         Company Name                                           Industry  \
# 0    TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 348  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
#
#     Round/Series  Amount                     Location
# 0           Seed  250000  Bangalore, Karnataka, India
# 348         Seed  250000  Bangalore, Karnataka, India

# %% [markdown]
# ##### We can see there is only one duplicated row, let's drop the row

# %%
# Dropping one of the duplicated row
data18.drop_duplicates(keep='first', inplace=True)

# %%
# Confirm if the duplicate rows have been dropped
duplicates = data18[data18.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Company Name, Industry, Round/Series, Amount, Location]
# Index: []

# %% [markdown]
# ### III. Check for missing values

# %%
missing_values_data18 = data18.isnull().sum()
missing_values_data18
# Out:
# Company Name    0
# Industry        0
# Round/Series    0
# Amount          0
# Location        0
# dtype: int64

# %% [markdown]
# #### We can see that there are no missing values. But missing values can be represented using '-', let's check

# %%
# Replacing '-' with NaN
data18.replace("—", np.nan, inplace=True)

# Check for missing values
missing_values_data18 = data18.isnull().sum()
missing_values_data18
# Out:
# Company Name      0
# Industry         30
# Round/Series      0
# Amount          148
# Location          0
# dtype: int64

# %% [markdown]
# #### Now we can see that we have a lot of missing values. Let's try dealing with the missing values

# %%
# Cleaning the 'Industry' column by replacing the missing values with 'Unknown'
data18['Industry'] = data18['Industry'].fillna('Unknown')
data18.head(10)
# Out:
#          Company Name                                           Industry  \
# 0     TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1     Happy Cow Dairy                               Agriculture, Farming
# 2          MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3         PayMe India                        Financial Services, FinTech
# 4            Eunimart                 E-Commerce Platforms, Retail, SaaS
# 5              Hasura                   Cloud Infrastructure, PaaS, SaaS
# 6           Tripshelf                     Internet, Leisure, Marketplace
# 7        Hyperdata.IO                                    Market Research
# 8        Freightwalla       Information Services, Information Technology
# 9  Microchip Payments                                    Mobile Payments
#
#   Round/Series       Amount                          Location
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed          NaN  Hyderabad, Andhra Pradesh, India
# 5         Seed      1600000       Bengaluru, Karnataka, India
# 6         Seed  ₹16,000,000             Kalkaji, Delhi, India
# 7        Angel  ₹50,000,000  Hyderabad, Andhra Pradesh, India
# 8         Seed          NaN        Mumbai, Maharashtra, India
# 9         Seed          NaN       Bangalore, Karnataka, India

# %%
# Cleaning the Location column by splitting at the commas
data18['Industry'].unique()
# Out:
# array(['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing',
#        'Agriculture, Farming',
#        'Credit, Financial Services, Lending, Marketplace',
#        'Financial Services, FinTech',
#        'E-Commerce Platforms, Retail, SaaS',
#        'Cloud Infrastructure, PaaS, SaaS',
#        'Internet, Leisure, Marketplace', 'Market Research',
#        'Information Services, Information Technology', 'Mobile Payments',
#        'B2B, Shoes', 'Internet',
#        'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat',
#        'Food Delivery', 'Industrial Automation',
#        'Automotive, Search Engine, Service Industry',
#        'Finance, Internet, Travel',
#        'Accounting, Business Information Systems, Business Travel, Finance, SaaS',
#        'Artificial Intelligence, Product Search, SaaS, Service Industry, Software',
#        'Internet of Things, Waste Management',
#        'Air Transportation, Freight Service, Logistics, Marine Transportation',
#        'Financial Services', 'Food and Beverage', 'Autonomous Vehicles',
#        'Enterprise Software, Health Care, Hospital, Parenting, Personal Health, SaaS',
#        'Agriculture, Analytics, Big Data, Farming',
#        'Logistics, Supply Chain Management',
#        'Financial Services, Lending',
#        'Automotive, Marketplace, Online Portals',
#        'Artificial Intelligence',
#        'Internet of Things, Telecommunications', 'Insurance',
#        'Information Technology, Logistics, Supply Chain Management',
#        'Blockchain, Developer Tools, Enterprise Software',
#        'Industrial Automation, Logistics, Supply Chain Management',
#        'Food and Beverage, Food Delivery, Snack Food', 'Education',
#        'E-Commerce, Fashion, Jewelry, Retail', 'Renewable Energy',
#        'E-Learning, Education',
#        'Clean Energy, CleanTech, Laundry and Dry-cleaning',
#        'E-Commerce, Fashion, Mobile',
#        'Apps, Messaging, Navigation, Public Safety', 'Transportation',
#        'Fitness, Health Care, Wellness',
#        'Artificial Intelligence, Machine Learning, SaaS, Virtual Assistant',
#        'Hospitality', 'Food and Beverage, Tea',
#        'Media and Entertainment, News, Outdoors',
#        'Broadcasting, Media and Entertainment, Music, Music Streaming, Video, Video Streaming',
#        'B2B, Information Services, Information Technology',
#        'EdTech, Education, Enterprise Software, Peer to Peer',
#        'Health Care, Medical', 'E-Commerce',
#        'Health Care, Hospital, Wellness', 'Unknown', 'Sports',
#        'Big Data, Consumer Lending, FinTech',
#        'Cloud Computing, Computer, Semiconductor',
#        'Health Care, Medical, Pharmaceutical', 'Food Processing, Retail',
#        'Trading Platform', "Consumer Goods, Lifestyle, Men's", 'Wellness',
#        'Food and Beverage, Food Processing, Nutrition', 'Fashion',
#        'Automotive, Electric Vehicle, Energy Storage',
#        'Consulting, Retail, Social',
#        'Biotechnology, Life Science, Pharmaceutical, Product Research',
#        'Health Care',
#        'Credit, Financial Services, FinTech, Personal Finance',
#        'Communities, Coworking, Incubators',
#        'Consumer, Financial Services, FinTech',
#        'Consumer Applications, Information Services, Location Based Services, Virtual Assistant',
#        'Mobile, Mobile Apps, Personalization, Test and Measurement, Web Apps',
#        'Education, Financial Services, FinTech',
#        'Advertising, Consulting, Digital Marketing',
#        'Marketplace, Real Estate, Rental Property',
#        'E-Learning, Internet, Video Games',
#        'Artificial Intelligence, Cloud Computing, Video',
#        'Health Care, Information Technology', 'Aerospace',
#        'E-Commerce, Fashion, Lifestyle',
#        'Artificial Intelligence, Business Intelligence, Industrial Automation, Machine Learning',
#        'Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home',
#        'EdTech, Education, Information Services, SaaS', 'Energy, Solar',
#        'B2B, Biometrics, Cyber Security, Fraud Detection, SaaS, Security',
#        'Artificial Intelligence, Social',
#        'Logistics, Transportation, Travel',
#        'Digital Marketing, SEM, SEO, Web Development',
#        'Health Care, Hospital, Medical', 'Finance, Financial Services',
#        'Food Delivery, Food Processing, Internet',
#        'E-Commerce, Food and Beverage, Internet',
#        'Fitness, Food and Beverage, Health Care, Nutrition',
#        'EdTech, Education, Knowledge Management',
#        'Apps, Beauty, Consumer, Retail',
#        'Creative Agency, Crowdfunding, EdTech, Health Care, Internet, Medical, Non Profit, Personal Health',
#        'Consumer Lending, Financial Services, FinTech, Insurance, Lending, Mobile Payments, Payments, Wealth Management',
#        'E-Learning, Education, Higher Education', 'Health Diagnostics',
#        'EdTech, Education', 'Financial Services, SaaS, Security',
#        'Banking, Finance, Financial Services, Non Profit',
#        'B2B, E-Commerce, Mobile',
#        'Automotive, Electric Vehicle, Renewable Energy', 'E-Learning',
#        'Embedded Systems, Health Care, Medical, Product Research',
#        'Apps, E-Commerce, Internet',
#        'Advertising, Human Resources, Marketing',
#        'Beauty, Fitness, Home Services, Internet',
#        'Health Care, Medical Device, Public Safety',
#        'Food Delivery, Online Portals, Restaurants',
#        'AgTech, B2B, Supply Chain Management',
#        'Credit Cards, Finance, Mobile Apps, Mobile Payments, Payments',
#        'Software',
#        'EdTech, Education, Higher Education, Secondary Education',
#        'Manufacturing, Retail', 'Manufacturing',
#        'Information Services, Information Technology, InsurTech',
#        'Consumer Lending, FinTech', 'Internet, Social Network, TV',
#        'Beauty, Health Care', 'Hospital', 'Events',
#        '3D Printing, Manufacturing, Product Design', 'Automotive',
#        'Automotive, Retail', 'Apps, Audio', 'Automotive, E-Commerce',
#        'Digital Entertainment, Fantasy Sports, Sports',
#        'E-Learning, EdTech, Education',
#        'Funding Platform, Incubators, Non Profit',
#        'Hospitality, Hotel, Leisure, Travel',
#        'Classifieds, Internet, Marketplace, Rental Property',
#        'Banking, E-Learning, Trading Platform',
#        'E-Commerce, Mobile, Retail',
#        'Artificial Intelligence, Information Technology',
#        'Enterprise Resource Planning (ERP), Information Services, Information Technology, Real Estate',
#        'Banking, Finance, Financial Services',
#        'Audio, Mobile, Tourism, Travel',
#        'Energy, Energy Storage, Infrastructure',
#        'Government, Information Technology, Software',
#        'Information Technology',
#        'Education, Information Technology, Internet, Mobile, Software',
#        'Consumer Lending, Financial Services, Lending, Personal Finance',
#        'Digital Media, Internet, Media and Entertainment, Online Portals, Social Media',
#        'Business Intelligence, Customer Service, Market Research, SaaS',
#        'Credit, Financial Services, FinTech, Lending',
#        'Children, Education, Parenting',
#        'Automotive, Battery, Energy, Energy Storage',
#        'E-Commerce, Mobile, Sharing Economy',
#        'Food Delivery, Organic, Organic Food', 'Mobile', 'Rental',
#        'Travel', 'Consumer', 'B2B, Farming, Marketplace',
#        'Wealth Management', 'Biotechnology',
#        'Education, Gaming, Training', 'Veterinary',
#        'Internet, Mobile, Social Entrepreneurship, Telecommunications, Wireless',
#        'Health Care, Hospital, Supply Chain Management',
#        'Tourism, Travel', 'Hospitality, Real Estate', 'Finance',
#        'Digital Media, EBooks, Publishing, Reading Apps',
#        'Consumer Electronics, Embedded Systems, Hardware, Smart Building, Software',
#        'Food and Beverage, Food Processing',
#        'Internet, Marketplace, Shopping',
#        'Analytics, Computer Vision, Enterprise Software, Machine Learning, Natural Language Processing, Speech Recognition',
#        'Facilities Support Services',
#        'Automotive, Electric Vehicle, Energy',
#        'Health Care, Health Diagnostics, Predictive Analytics',
#        'Cloud Computing, Computer, SaaS, Software',
#        'Fashion, Lifestyle, Retail', 'Medical', 'Music Streaming',
#        'Finance, Impact Investing, Internet',
#        'Internet, Social Entrepreneurship', 'Retail',
#        'Finance, Impact Investing, Mobile Apps',
#        'Cloud Computing, Computer, Software',
#        'Business Development, Market Research, Outsourcing',
#        'Health Care, Hospitality', 'Internet, Social News, Sports',
#        'Human Resources', 'Finance, Financial Services, FinTech',
#        'Customer Service, Software, Video, Video Streaming',
#        'E-Commerce, Food Processing', 'Training',
#        'Dietary Supplements, Food and Beverage, Health Care, Organic Food, Snack Food',
#        'Manufacturing, Oil and Gas, Robotics',
#        'Artificial Intelligence, Computer, Machine Learning',
#        'Collaboration, Communities, Coworking, Sharing Economy',
#        'Big Data, EdTech, Machine Learning', 'Nanotechnology',
#        'Analytics, Audio, Digital Media, Innovation Management, Internet Radio, Media and Entertainment',
#        'Financial Services, Lending, Peer to Peer',
#        'E-Commerce, Furniture, Home Decor, Interior Design, Internet',
#        'Digital Media', 'File Sharing, Personalization, Social Media',
#        'Home Decor, Interior Design',
#        'Health Care, Medical Device, Mobile Apps',
#        'E-Commerce, Facilities Support Services, Procurement, Supply Chain Management',
#        'Crowdfunding, Finance, Financial Services',
#        'Finance, Financial Services, Insurance',
#        'Children, Education, Online Portals', 'Software, Virtual Reality',
#        'B2B, Food and Beverage, Food Delivery',
#        'Catering, Food and Beverage, Food Delivery, Food Processing',
#        'Food and Beverage, Snack Food', 'Automotive, E-Commerce, Mobile',
#        'Computer, Digital Marketing, Facilities Support Services, Graphic Design, Internet, Mobile Apps, Social Media Marketing, Web Development',
#        'Android, Big Data, Blockchain, Cloud Computing, EdTech, Education, Information Technology, iOS, Training, Web Development',
#        'Analytics, CRM, Loyalty Programs, Machine Learning, Marketing Automation, Retail Technology, SaaS, Small and Medium Businesses',
#        'Delivery, Information Technology, Mobile Apps',
#        'Environmental Consulting, Renewable Energy',
#        'Big Data, Business Intelligence, Financial Services, FinTech, Personal Finance',
#        'Commercial Real Estate, Coworking, Office Administration, Real Estate',
#        'Food and Beverage, Food Processing, Organic Food, Snack Food',
#        'Apps, Health Care, Internet, Mobile Apps, Personal Health',
#        'Digital Media, Incubators, Social Entrepreneurship',
#        'Finance, Financial Services, Marketing',
#        'Biotechnology, Health Care, Life Science, Medical Device',
#        'Education, Human Resources', 'Consumer Electronics',
#        'Apps, Health Care, Hospital, Mobile Apps',
#        'Delivery Service, Logistics, Service Industry',
#        'Big Data, Data Visualization, Logistics, Software',
#        'Basketball, Cricket, Cycling, eSports, Fitness, Golf, Health Care, Hockey, Sports, Swimming, Table Tennis, Volley Ball',
#        'Media and Entertainment, News, Publishing', 'Consulting',
#        'Big Data, Financial Services, Machine Learning, Predictive Analytics',
#        'Agriculture, AgTech, Manufacturing',
#        'Digital Media, News, Publishing', 'Health Care, Hospital',
#        'B2B, E-Commerce, Enterprise',
#        'Fraud Detection, Information Services, Security',
#        'Agriculture, AgTech, Artificial Intelligence, Internet of Things, Machine Learning',
#        'Cryptocurrency, Trading Platform',
#        'Finance, FinTech, Mobile Payments', 'Wedding',
#        'E-Learning, EdTech, Education, Image Recognition, Machine Learning, STEM Education',
#        'Consumer Goods', 'Digital Entertainment',
#        'Crowdsourcing, Financial Services, Funding Platform, Venture Capital',
#        'Delivery, Drones, Geospatial, Robotics',
#        'Health Care, Information Technology, Management Information Systems',
#        'Farming',
#        'Business Travel, Hospitality, Hotel, Marketplace, Tourism, Travel Accommodations',
#        'Career Planning, Education, Higher Education, Service Industry',
#        'Medical Device', 'Alternative Medicine, Health Care',
#        'Internet, Software',
#        'Dental, Elder Care, Health Care, Home Health Care, Personal Health',
#        'Financial Services, Insurance, Private Social Networking',
#        'Consumer Electronics, E-Commerce, E-Commerce Platforms, Electronics, Shipping, Shopping',
#        'CleanTech', 'Advertising, Internet, Marketing',
#        'Human Resources, Security, Training',
#        'Consumer Lending, Finance, FinTech',
#        'Marketing, Social Media, Video', 'Banking', 'Food Processing',
#        'Apps', 'Marketing',
#        'Apps, B2B, Freight Service, Logistics, SaaS, Shipping, Supply Chain Management, Transportation',
#        'Digital Entertainment, Fantasy Sports, Gaming, Sports',
#        'Automotive, Last Mile Transportation, Peer to Peer, Ride Sharing',
#        'Commercial, E-Learning, Education',
#        'Continuing Education, EdTech, Education, Skill Assessment',
#        'Smart Cities, Telecommunications', 'Internet of Things, Robotics',
#        'Apps, Home Services, Information Services, Information Technology',
#        'Medical, Tourism', 'Career Planning, Education, Internet',
#        'Fashion, Graphic Design, Wearables',
#        'Communities, Leisure, Mobile Apps, Software',
#        'Automotive, Rental, Sharing Economy',
#        'Energy, Environmental Consulting, Renewable Energy, Solar',
#        'Information Technology, SaaS, Security',
#        'Crowdfunding, Financial Services, Internet',
#        'Customer Service, Information Technology, Internet, Sales Automation',
#        'Advertising, Artificial Intelligence, Digital Media, iOS, Location Based Services, News, Video, Video on Demand, Video Streaming',
#        'Credit Cards, Payments, Property Insurance, Property Management, Rental Property',
#        'Beauty, Cosmetics, Health Care, Service Industry',
#        'EdTech, Education, Mobile, Tutoring', 'Social Media, Sports',
#        'Biopharma', 'E-Commerce, E-Commerce Platforms, Retail',
#        'E-Commerce, Fashion, Shopping',
#        'Digital Entertainment, Mobile, PC Games',
#        'Finance, Financial Services, Small and Medium Businesses',
#        'Artificial Intelligence, Energy, Oil and Gas',
#        'Computer, FinTech, Risk Management, Software',
#        'Apps, Financial Services, FinTech',
#        "Child Care, Health Care, Hospital, Medical, Women's",
#        'Agriculture, Mobile',
#        'Finance, FinTech, Payments, Property Development, Rental',
#        'Information Services, Information Technology, Mobile, Software',
#        'Apps, Fitness, Health Care, mHealth',
#        'Food and Beverage, Food Delivery', 'Apps, Payments, Retail',
#        'Health Insurance, Insurance, Life Insurance',
#        'Rental, Taxi Service, Travel',
#        'E-Commerce, E-Commerce Platforms, Internet, Retail',
#        'Financial Services, Professional Services',
#        'Customer Service, Messaging, Mobile Apps, Personalization',
#        'Gaming, iOS, Sports',
#        'E-Commerce, E-Commerce Platforms, Internet, Mobile Apps, Social Media',
#        'Search Engine',
#        'Battery, Electric Vehicle, Energy, Renewable Energy, Transportation',
#        'Agriculture, Farmers Market, Farming',
#        'Artificial Intelligence, Drones, Navigation, Packaging Services, Robotics',
#        'Fitness, GreenTech, Internet of Things, Mobile Apps, Ride Sharing, Transportation',
#        'Mobile, Software, Travel', 'Cosmetics',
#        'Consulting, Cyber Security, Network Security',
#        'eSports, Gaming, Video Games', 'Fashion, Jewelry',
#        'B2B, Medical Device', 'Consumer Goods, Manufacturing',
#        'Biotechnology, Health Care, Wellness',
#        'Health Care, Hospital, Medical, Robotics',
#        'E-Commerce, Fitness, Health Care',
#        'Financial Services, Venture Capital', 'Accounting, Apps, FinTech',
#        'Apps, Mobile, Transportation', 'Reading Apps',
#        'Energy, Renewable Energy, Solar',
#        'Banking, Financial Services, FinTech', 'Apps, Education, Retail',
#        'Electric Vehicle',
#        'Automotive, Battery, Electric Vehicle, Manufacturing, Mechanical Design',
#        'Automotive, E-Commerce, Marketplace', 'Agriculture',
#        'Apps, Information Services, Information Technology',
#        'B2B, Marketplace', 'Packaging Services',
#        'Computer, Furniture, Software',
#        'Food Delivery, Hospitality, Reservations, Restaurants, Search Engine',
#        'Collaboration, Communities, Coworking, Real Estate',
#        'Accounting, Banking, Finance',
#        'Cloud Computing, Enterprise Software, Network Hardware, Network Security, SaaS',
#        'Information Services, Internet, Logistics, Supply Chain Management, Transportation',
#        'Automotive, E-Commerce, Information Services',
#        'Delivery, Logistics, Transportation',
#        'Automotive, E-Commerce Platforms, Marketplace',
#        'Last Mile Transportation, Railroad, Transportation, Travel',
#        'Cooking, E-Commerce, Food and Beverage, Food Delivery, Online Portals',
#        'FinTech, Mobile, Mobile Payments, Payments, Retail Technology',
#        'Online Games, Software',
#        'Online Portals, Property Management, Rental',
#        'E-Commerce, Food and Beverage, Tea',
#        'Music, Social Network, Video',
#        'Health Care, Pharmaceutical, Wellness',
#        'Delivery Service, Food and Beverage, Food Delivery',
#        'Hospitality, Information Technology, Travel Accommodations',
#        'Biotechnology, Diabetes, Health Care',
#        'Autonomous Vehicles, Last Mile Transportation, Recreational Vehicles, Rental',
#        'Finance, Financial Exchanges, Financial Services, Micro Lending',
#        'Analytics, Apps, Market Research',
#        'E-Commerce, E-Commerce Platforms, Furniture, Home Decor, Internet',
#        'Apps, Mobile, Mobile Apps, Software',
#        'News, Publishing, Social Media',
#        'Industrial, Industrial Automation',
#        'Internet, Mobile Apps, Social Network',
#        'Health Care, Health Diagnostics, Internet of Things, Life Science, Machine Learning, Medical, Medical Device',
#        'E-Commerce, Furniture, Interior Design', 'Apps, Events, News',
#        'Artificial Intelligence, Human Resources, Information Services, Information Technology',
#        'Logistics, Railroad, Transportation',
#        'Dating, Private Social Networking',
#        'Artificial Intelligence, Machine Learning, PaaS',
#        'Consumer, Furniture, Home Decor, Home Improvement',
#        'Apps, E-Commerce, Internet, Mobile, Ride Sharing, Transportation',
#        'Health Care, Health Insurance', 'Energy, Natural Resources',
#        'E-Commerce, Education, Health Care',
#        'Apps, Health Care, Pharmaceutical',
#        'Internet, Knowledge Management',
#        'Credit, Finance, FinTech, Lending, Sales Automation',
#        'Banking, Financial Services, Internet',
#        'E-Commerce, Health Care, Retail',
#        'Child Care, Information Technology',
#        'Financial Services, Micro Lending',
#        'E-Commerce, Retail, Shopping',
#        'Food and Beverage, Snack Food, Tea',
#        'Delivery Service, E-Commerce, Logistics',
#        'Fashion, Lifestyle, Rental', 'Fantasy Sports, Mobile, Sports',
#        'Beauty, Fashion, Wellness', 'Food and Beverage, Restaurants, Tea',
#        'Fitness, Sporting Goods, Sports',
#        'Food and Beverage, Food Processing, Manufacturing',
#        'E-Learning, Internet', 'Eyewear, Internet',
#        'Information Technology, Mobile, News, Operating Systems, Social Media, Social News',
#        'FinTech, Internet, Payments, Service Industry',
#        'B2B, Business Development, Internet, Marketplace',
#        'Food and Beverage, Food Delivery, Internet',
#        'Biotechnology, Health Care, Pharmaceutical'], dtype=object)

# %%
# Cleaning the Location Industry by splitting at the commas
data18[["City", "State", "Country"]]= data18['Location'].str.split(',', expand=True)
data18
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount                          Location       City  \
# 0           Seed       250000       Bangalore, Karnataka, India  Bangalore
# 1           Seed  ₹40,000,000        Mumbai, Maharashtra, India     Mumbai
# 2       Series A  ₹65,000,000           Gurgaon, Haryana, India    Gurgaon
# 3          Angel      2000000       Noida, Uttar Pradesh, India      Noida
# 4           Seed          NaN  Hyderabad, Andhra Pradesh, India  Hyderabad
# ..           ...          ...                               ...        ...
# 521     Series C    225000000       Bangalore, Karnataka, India  Bangalore
# 522     Series A          NaN           Haryana, Haryana, India    Haryana
# 523         Seed         7500        Mumbai, Maharashtra, India     Mumbai
# 524         Seed  ₹35,000,000        Mumbai, Maharashtra, India     Mumbai
# 525     Series C     35000000        Chennai, Tamil Nadu, India    Chennai
#
#                State Country
# 0          Karnataka   India
# 1        Maharashtra   India
# 2            Haryana   India
# 3      Uttar Pradesh   India
# 4     Andhra Pradesh   India
# ..               ...     ...
# 521        Karnataka   India
# 522          Haryana   India
# 523      Maharashtra   India
# 524      Maharashtra   India
# 525       Tamil Nadu   India
#
# [525 rows x 8 columns]

# %%
# Replace '$' currency symbol and commas with empty string
data18['Amount'] = data18['Amount'].str.replace(',', '', regex=False).str.replace('$', '', regex=False)

# Cleaning the 'Amount' column by converting Indian Rupees to USD
data18.loc[data18['Amount'].astype(str).str.contains('₹'), 'Amount'] = data18.loc[data18['Amount'].astype(str).str.contains('₹'),'Amount'].apply(lambda x: float(x.replace('₹', ''))*0.012)

# Converting the 'Amount' column to numeric datatype, replacing any non-numeric values with NaN
data18['Amount'] = pd.to_numeric(data18['Amount'], errors='coerce')

# Rename column "Amount" to "Amount($)"
data18.rename(columns={'Amount':'Amount($)'}, inplace=True)

# Convert Amount($) column from object to float datatype
data18['Amount($)'] = data18['Amount($)'].astype(float)

data18
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series    Amount($)                          Location       City  \
# 0           Seed    250000.00       Bangalore, Karnataka, India  Bangalore
# 1           Seed    480000.00        Mumbai, Maharashtra, India     Mumbai
# 2       Series A    780000.00           Gurgaon, Haryana, India    Gurgaon
# 3          Angel   2000000.00       Noida, Uttar Pradesh, India      Noida
# 4           Seed          NaN  Hyderabad, Andhra Pradesh, India  Hyderabad
# ..           ...          ...                               ...        ...
# 521     Series C 225000000.00       Bangalore, Karnataka, India  Bangalore
# 522     Series A          NaN           Haryana, Haryana, India    Haryana
# 523         Seed      7500.00        Mumbai, Maharashtra, India     Mumbai
# 524         Seed    420000.00        Mumbai, Maharashtra, India     Mumbai
# 525     Series C  35000000.00        Chennai, Tamil Nadu, India    Chennai
#
#                State Country
# 0          Karnataka   India
# 1        Maharashtra   India
# 2            Haryana   India
# 3      Uttar Pradesh   India
# 4     Andhra Pradesh   India
# ..               ...     ...
# 521        Karnataka   India
# 522          Haryana   India
# 523      Maharashtra   India
# 524      Maharashtra   India
# 525       Tamil Nadu   India
#
# [525 rows x 8 columns]

# %%
# Replace NaN values in 'Amount($)' column with median
# Calculate the median of 'Amount($)' column
mean_amount = data18['Amount($)'].mean()

# Replacing NaN with the mean
data18['Amount($)'].fillna(value=mean_amount, inplace=True)

data18
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series    Amount($)                          Location       City  \
# 0           Seed    250000.00       Bangalore, Karnataka, India  Bangalore
# 1           Seed    480000.00        Mumbai, Maharashtra, India     Mumbai
# 2       Series A    780000.00           Gurgaon, Haryana, India    Gurgaon
# 3          Angel   2000000.00       Noida, Uttar Pradesh, India      Noida
# 4           Seed  17030531.59  Hyderabad, Andhra Pradesh, India  Hyderabad
# ..           ...          ...                               ...        ...
# 521     Series C 225000000.00       Bangalore, Karnataka, India  Bangalore
# 522     Series A  17030531.59           Haryana, Haryana, India    Haryana
# 523         Seed      7500.00        Mumbai, Maharashtra, India     Mumbai
# 524         Seed    420000.00        Mumbai, Maharashtra, India     Mumbai
# 525     Series C  35000000.00        Chennai, Tamil Nadu, India    Chennai
#
#                State Country
# 0          Karnataka   India
# 1        Maharashtra   India
# 2            Haryana   India
# 3      Uttar Pradesh   India
# 4     Andhra Pradesh   India
# ..               ...     ...
# 521        Karnataka   India
# 522          Haryana   India
# 523      Maharashtra   India
# 524      Maharashtra   India
# 525       Tamil Nadu   India
#
# [525 rows x 8 columns]

# %%
# Creating a year column and filling with 2018
data18.insert(0,'Year', 2018)
data18.head()
# Out:
#    Year     Company Name                                           Industry  \
# 0  2018  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  2018  Happy Cow Dairy                               Agriculture, Farming
# 2  2018       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3  2018      PayMe India                        Financial Services, FinTech
# 4  2018         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series   Amount($)                          Location       City  \
# 0         Seed   250000.00       Bangalore, Karnataka, India  Bangalore
# 1         Seed   480000.00        Mumbai, Maharashtra, India     Mumbai
# 2     Series A   780000.00           Gurgaon, Haryana, India    Gurgaon
# 3        Angel  2000000.00       Noida, Uttar Pradesh, India      Noida
# 4         Seed 17030531.59  Hyderabad, Andhra Pradesh, India  Hyderabad
#
#              State Country
# 0        Karnataka   India
# 1      Maharashtra   India
# 2          Haryana   India
# 3    Uttar Pradesh   India
# 4   Andhra Pradesh   India

# %%
# Cleaning the Location column by splitting at the commas
data18[["City", "State", "Country"]]= data18['Location'].str.split(',', expand=True)
data18
# Out:
#      Year       Company Name  \
# 0    2018    TheCollegeFever
# 1    2018    Happy Cow Dairy
# 2    2018         MyLoanCare
# 3    2018        PayMe India
# 4    2018           Eunimart
# ..    ...                ...
# 521  2018              Udaan
# 522  2018  Happyeasygo Group
# 523  2018             Mombay
# 524  2018         Droni Tech
# 525  2018            Netmeds
#
#                                               Industry Round/Series  \
# 0    Brand Marketing, Event Promotion, Marketing, S...         Seed
# 1                                 Agriculture, Farming         Seed
# 2     Credit, Financial Services, Lending, Marketplace     Series A
# 3                          Financial Services, FinTech        Angel
# 4                   E-Commerce Platforms, Retail, SaaS         Seed
# ..                                                 ...          ...
# 521   B2B, Business Development, Internet, Marketplace     Series C
# 522                                    Tourism, Travel     Series A
# 523         Food and Beverage, Food Delivery, Internet         Seed
# 524                             Information Technology         Seed
# 525         Biotechnology, Health Care, Pharmaceutical     Series C
#
#        Amount($)                          Location       City  \
# 0      250000.00       Bangalore, Karnataka, India  Bangalore
# 1      480000.00        Mumbai, Maharashtra, India     Mumbai
# 2      780000.00           Gurgaon, Haryana, India    Gurgaon
# 3     2000000.00       Noida, Uttar Pradesh, India      Noida
# 4    17030531.59  Hyderabad, Andhra Pradesh, India  Hyderabad
# ..           ...                               ...        ...
# 521 225000000.00       Bangalore, Karnataka, India  Bangalore
# 522  17030531.59           Haryana, Haryana, India    Haryana
# 523      7500.00        Mumbai, Maharashtra, India     Mumbai
# 524    420000.00        Mumbai, Maharashtra, India     Mumbai
# 525  35000000.00        Chennai, Tamil Nadu, India    Chennai
#
#                State Country
# 0          Karnataka   India
# 1        Maharashtra   India
# 2            Haryana   India
# 3      Uttar Pradesh   India
# 4     Andhra Pradesh   India
# ..               ...     ...
# 521        Karnataka   India
# 522          Haryana   India
# 523      Maharashtra   India
# 524      Maharashtra   India
# 525       Tamil Nadu   India
#
# [525 rows x 9 columns]

# %%
# Dropping the Country and Location column as it is not needed for the analysis
columns_to_drop = ['Country','Location','State']
data18.drop(columns_to_drop, axis=1, inplace=True)
data18.head()
# Out:
#    Year     Company Name                                           Industry  \
# 0  2018  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  2018  Happy Cow Dairy                               Agriculture, Farming
# 2  2018       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3  2018      PayMe India                        Financial Services, FinTech
# 4  2018         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series   Amount($)       City
# 0         Seed   250000.00  Bangalore
# 1         Seed   480000.00     Mumbai
# 2     Series A   780000.00    Gurgaon
# 3        Angel  2000000.00      Noida
# 4         Seed 17030531.59  Hyderabad

# %%
# Check for missing values
data18.isna().sum()
# Out:
# Year            0
# Company Name    0
# Industry        0
# Round/Series    0
# Amount($)       0
# City            0
# dtype: int64

# %%
# Check the data types
data18.dtypes
# Out:
# Year              int64
# Company Name     object
# Industry         object
# Round/Series     object
# Amount($)       float64
# City             object
# dtype: object

# %%
#Inspecting the City and State columns
data18['City'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad',
#        'Bengaluru', 'Kalkaji', 'Delhi', 'India', 'Hubli', 'New Delhi',
#        'Chennai', 'Mohali', 'Kolkata', 'Pune', 'Jodhpur', 'Kanpur',
#        'Ahmedabad', 'Azadpur', 'Haryana', 'Cochin', 'Faridabad', 'Jaipur',
#        'Kota', 'Anand', 'Bangalore City', 'Belgaum', 'Thane', 'Margão',
#        'Indore', 'Alwar', 'Kannur', 'Trivandrum', 'Ernakulam',
#        'Kormangala', 'Uttar Pradesh', 'Andheri', 'Mylapore', 'Ghaziabad',
#        'Kochi', 'Powai', 'Guntur', 'Kalpakkam', 'Bhopal', 'Coimbatore',
#        'Worli', 'Alleppey', 'Chandigarh', 'Guindy', 'Lucknow'],
#       dtype=object)

# %%
# Replacing Bengaluru and Bangalore City with Bangalore
data18['City'] = data18['City'].str.replace('Bangalore','Bengaluru', case=False)
data18['City'] = data18['City'].str.replace('Bangalore City','Bengaluru', case=False) 
data18['City'].unique()
# Out:
# array(['Bengaluru', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad', 'Kalkaji',
#        'Delhi', 'India', 'Hubli', 'New Delhi', 'Chennai', 'Mohali',
#        'Kolkata', 'Pune', 'Jodhpur', 'Kanpur', 'Ahmedabad', 'Azadpur',
#        'Haryana', 'Cochin', 'Faridabad', 'Jaipur', 'Kota', 'Anand',
#        'Bengaluru City', 'Belgaum', 'Thane', 'Margão', 'Indore', 'Alwar',
#        'Kannur', 'Trivandrum', 'Ernakulam', 'Kormangala', 'Uttar Pradesh',
#        'Andheri', 'Mylapore', 'Ghaziabad', 'Kochi', 'Powai', 'Guntur',
#        'Kalpakkam', 'Bhopal', 'Coimbatore', 'Worli', 'Alleppey',
#        'Chandigarh', 'Guindy', 'Lucknow'], dtype=object)

# %%
#Renaming the City column to Headquarter and company name to company/Brand, same as round/series to stage
data18.rename(columns={'City':'HeadQuarter'}, inplace=True)
data18.rename(columns={'Company Name':'Company/Brand'}, inplace=True)
data18.rename(columns={'Round/Series':'Stage'}, inplace=True)
data18.rename(columns={'Industry':'Sector'}, inplace=True)

# %%
data18
# Out:
#      Year      Company/Brand  \
# 0    2018    TheCollegeFever
# 1    2018    Happy Cow Dairy
# 2    2018         MyLoanCare
# 3    2018        PayMe India
# 4    2018           Eunimart
# ..    ...                ...
# 521  2018              Udaan
# 522  2018  Happyeasygo Group
# 523  2018             Mombay
# 524  2018         Droni Tech
# 525  2018            Netmeds
#
#                                                 Sector     Stage    Amount($)  \
# 0    Brand Marketing, Event Promotion, Marketing, S...      Seed    250000.00
# 1                                 Agriculture, Farming      Seed    480000.00
# 2     Credit, Financial Services, Lending, Marketplace  Series A    780000.00
# 3                          Financial Services, FinTech     Angel   2000000.00
# 4                   E-Commerce Platforms, Retail, SaaS      Seed  17030531.59
# ..                                                 ...       ...          ...
# 521   B2B, Business Development, Internet, Marketplace  Series C 225000000.00
# 522                                    Tourism, Travel  Series A  17030531.59
# 523         Food and Beverage, Food Delivery, Internet      Seed      7500.00
# 524                             Information Technology      Seed    420000.00
# 525         Biotechnology, Health Care, Pharmaceutical  Series C  35000000.00
#
#     HeadQuarter
# 0     Bengaluru
# 1        Mumbai
# 2       Gurgaon
# 3         Noida
# 4     Hyderabad
# ..          ...
# 521   Bengaluru
# 522     Haryana
# 523      Mumbai
# 524      Mumbai
# 525     Chennai
#
# [525 rows x 6 columns]

# %%
#Inspecting the Stage Column
data18['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed',
#        'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round'], dtype=object)

# %%
#Replace the link and with unknown
data18['Stage'] = data18['Stage'].str.replace('https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593','Undisclosed', case=False)

# %%
data18['Stage'].value_counts(ascending= False)
# Out:
# Seed                        279
# Series A                     73
# Angel                        37
# Venture - Series Unknown     37
# Series B                     20
# Series C                     16
# Debt Financing               13
# Private Equity               10
# Corporate Round               8
# Pre-Seed                      6
# Series E                      5
# Grant                         4
# Series D                      3
# Secondary Market              3
# Post-IPO Equity               3
# Undisclosed                   3
# Post-IPO Debt                 2
# Non-equity Assistance         1
# Series H                      1
# Funding Round                 1
# Name: Stage, dtype: int64

# %%
data18['Sector'].unique()
# Out:
# array(['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing',
#        'Agriculture, Farming',
#        'Credit, Financial Services, Lending, Marketplace',
#        'Financial Services, FinTech',
#        'E-Commerce Platforms, Retail, SaaS',
#        'Cloud Infrastructure, PaaS, SaaS',
#        'Internet, Leisure, Marketplace', 'Market Research',
#        'Information Services, Information Technology', 'Mobile Payments',
#        'B2B, Shoes', 'Internet',
#        'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat',
#        'Food Delivery', 'Industrial Automation',
#        'Automotive, Search Engine, Service Industry',
#        'Finance, Internet, Travel',
#        'Accounting, Business Information Systems, Business Travel, Finance, SaaS',
#        'Artificial Intelligence, Product Search, SaaS, Service Industry, Software',
#        'Internet of Things, Waste Management',
#        'Air Transportation, Freight Service, Logistics, Marine Transportation',
#        'Financial Services', 'Food and Beverage', 'Autonomous Vehicles',
#        'Enterprise Software, Health Care, Hospital, Parenting, Personal Health, SaaS',
#        'Agriculture, Analytics, Big Data, Farming',
#        'Logistics, Supply Chain Management',
#        'Financial Services, Lending',
#        'Automotive, Marketplace, Online Portals',
#        'Artificial Intelligence',
#        'Internet of Things, Telecommunications', 'Insurance',
#        'Information Technology, Logistics, Supply Chain Management',
#        'Blockchain, Developer Tools, Enterprise Software',
#        'Industrial Automation, Logistics, Supply Chain Management',
#        'Food and Beverage, Food Delivery, Snack Food', 'Education',
#        'E-Commerce, Fashion, Jewelry, Retail', 'Renewable Energy',
#        'E-Learning, Education',
#        'Clean Energy, CleanTech, Laundry and Dry-cleaning',
#        'E-Commerce, Fashion, Mobile',
#        'Apps, Messaging, Navigation, Public Safety', 'Transportation',
#        'Fitness, Health Care, Wellness',
#        'Artificial Intelligence, Machine Learning, SaaS, Virtual Assistant',
#        'Hospitality', 'Food and Beverage, Tea',
#        'Media and Entertainment, News, Outdoors',
#        'Broadcasting, Media and Entertainment, Music, Music Streaming, Video, Video Streaming',
#        'B2B, Information Services, Information Technology',
#        'EdTech, Education, Enterprise Software, Peer to Peer',
#        'Health Care, Medical', 'E-Commerce',
#        'Health Care, Hospital, Wellness', 'Unknown', 'Sports',
#        'Big Data, Consumer Lending, FinTech',
#        'Cloud Computing, Computer, Semiconductor',
#        'Health Care, Medical, Pharmaceutical', 'Food Processing, Retail',
#        'Trading Platform', "Consumer Goods, Lifestyle, Men's", 'Wellness',
#        'Food and Beverage, Food Processing, Nutrition', 'Fashion',
#        'Automotive, Electric Vehicle, Energy Storage',
#        'Consulting, Retail, Social',
#        'Biotechnology, Life Science, Pharmaceutical, Product Research',
#        'Health Care',
#        'Credit, Financial Services, FinTech, Personal Finance',
#        'Communities, Coworking, Incubators',
#        'Consumer, Financial Services, FinTech',
#        'Consumer Applications, Information Services, Location Based Services, Virtual Assistant',
#        'Mobile, Mobile Apps, Personalization, Test and Measurement, Web Apps',
#        'Education, Financial Services, FinTech',
#        'Advertising, Consulting, Digital Marketing',
#        'Marketplace, Real Estate, Rental Property',
#        'E-Learning, Internet, Video Games',
#        'Artificial Intelligence, Cloud Computing, Video',
#        'Health Care, Information Technology', 'Aerospace',
#        'E-Commerce, Fashion, Lifestyle',
#        'Artificial Intelligence, Business Intelligence, Industrial Automation, Machine Learning',
#        'Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home',
#        'EdTech, Education, Information Services, SaaS', 'Energy, Solar',
#        'B2B, Biometrics, Cyber Security, Fraud Detection, SaaS, Security',
#        'Artificial Intelligence, Social',
#        'Logistics, Transportation, Travel',
#        'Digital Marketing, SEM, SEO, Web Development',
#        'Health Care, Hospital, Medical', 'Finance, Financial Services',
#        'Food Delivery, Food Processing, Internet',
#        'E-Commerce, Food and Beverage, Internet',
#        'Fitness, Food and Beverage, Health Care, Nutrition',
#        'EdTech, Education, Knowledge Management',
#        'Apps, Beauty, Consumer, Retail',
#        'Creative Agency, Crowdfunding, EdTech, Health Care, Internet, Medical, Non Profit, Personal Health',
#        'Consumer Lending, Financial Services, FinTech, Insurance, Lending, Mobile Payments, Payments, Wealth Management',
#        'E-Learning, Education, Higher Education', 'Health Diagnostics',
#        'EdTech, Education', 'Financial Services, SaaS, Security',
#        'Banking, Finance, Financial Services, Non Profit',
#        'B2B, E-Commerce, Mobile',
#        'Automotive, Electric Vehicle, Renewable Energy', 'E-Learning',
#        'Embedded Systems, Health Care, Medical, Product Research',
#        'Apps, E-Commerce, Internet',
#        'Advertising, Human Resources, Marketing',
#        'Beauty, Fitness, Home Services, Internet',
#        'Health Care, Medical Device, Public Safety',
#        'Food Delivery, Online Portals, Restaurants',
#        'AgTech, B2B, Supply Chain Management',
#        'Credit Cards, Finance, Mobile Apps, Mobile Payments, Payments',
#        'Software',
#        'EdTech, Education, Higher Education, Secondary Education',
#        'Manufacturing, Retail', 'Manufacturing',
#        'Information Services, Information Technology, InsurTech',
#        'Consumer Lending, FinTech', 'Internet, Social Network, TV',
#        'Beauty, Health Care', 'Hospital', 'Events',
#        '3D Printing, Manufacturing, Product Design', 'Automotive',
#        'Automotive, Retail', 'Apps, Audio', 'Automotive, E-Commerce',
#        'Digital Entertainment, Fantasy Sports, Sports',
#        'E-Learning, EdTech, Education',
#        'Funding Platform, Incubators, Non Profit',
#        'Hospitality, Hotel, Leisure, Travel',
#        'Classifieds, Internet, Marketplace, Rental Property',
#        'Banking, E-Learning, Trading Platform',
#        'E-Commerce, Mobile, Retail',
#        'Artificial Intelligence, Information Technology',
#        'Enterprise Resource Planning (ERP), Information Services, Information Technology, Real Estate',
#        'Banking, Finance, Financial Services',
#        'Audio, Mobile, Tourism, Travel',
#        'Energy, Energy Storage, Infrastructure',
#        'Government, Information Technology, Software',
#        'Information Technology',
#        'Education, Information Technology, Internet, Mobile, Software',
#        'Consumer Lending, Financial Services, Lending, Personal Finance',
#        'Digital Media, Internet, Media and Entertainment, Online Portals, Social Media',
#        'Business Intelligence, Customer Service, Market Research, SaaS',
#        'Credit, Financial Services, FinTech, Lending',
#        'Children, Education, Parenting',
#        'Automotive, Battery, Energy, Energy Storage',
#        'E-Commerce, Mobile, Sharing Economy',
#        'Food Delivery, Organic, Organic Food', 'Mobile', 'Rental',
#        'Travel', 'Consumer', 'B2B, Farming, Marketplace',
#        'Wealth Management', 'Biotechnology',
#        'Education, Gaming, Training', 'Veterinary',
#        'Internet, Mobile, Social Entrepreneurship, Telecommunications, Wireless',
#        'Health Care, Hospital, Supply Chain Management',
#        'Tourism, Travel', 'Hospitality, Real Estate', 'Finance',
#        'Digital Media, EBooks, Publishing, Reading Apps',
#        'Consumer Electronics, Embedded Systems, Hardware, Smart Building, Software',
#        'Food and Beverage, Food Processing',
#        'Internet, Marketplace, Shopping',
#        'Analytics, Computer Vision, Enterprise Software, Machine Learning, Natural Language Processing, Speech Recognition',
#        'Facilities Support Services',
#        'Automotive, Electric Vehicle, Energy',
#        'Health Care, Health Diagnostics, Predictive Analytics',
#        'Cloud Computing, Computer, SaaS, Software',
#        'Fashion, Lifestyle, Retail', 'Medical', 'Music Streaming',
#        'Finance, Impact Investing, Internet',
#        'Internet, Social Entrepreneurship', 'Retail',
#        'Finance, Impact Investing, Mobile Apps',
#        'Cloud Computing, Computer, Software',
#        'Business Development, Market Research, Outsourcing',
#        'Health Care, Hospitality', 'Internet, Social News, Sports',
#        'Human Resources', 'Finance, Financial Services, FinTech',
#        'Customer Service, Software, Video, Video Streaming',
#        'E-Commerce, Food Processing', 'Training',
#        'Dietary Supplements, Food and Beverage, Health Care, Organic Food, Snack Food',
#        'Manufacturing, Oil and Gas, Robotics',
#        'Artificial Intelligence, Computer, Machine Learning',
#        'Collaboration, Communities, Coworking, Sharing Economy',
#        'Big Data, EdTech, Machine Learning', 'Nanotechnology',
#        'Analytics, Audio, Digital Media, Innovation Management, Internet Radio, Media and Entertainment',
#        'Financial Services, Lending, Peer to Peer',
#        'E-Commerce, Furniture, Home Decor, Interior Design, Internet',
#        'Digital Media', 'File Sharing, Personalization, Social Media',
#        'Home Decor, Interior Design',
#        'Health Care, Medical Device, Mobile Apps',
#        'E-Commerce, Facilities Support Services, Procurement, Supply Chain Management',
#        'Crowdfunding, Finance, Financial Services',
#        'Finance, Financial Services, Insurance',
#        'Children, Education, Online Portals', 'Software, Virtual Reality',
#        'B2B, Food and Beverage, Food Delivery',
#        'Catering, Food and Beverage, Food Delivery, Food Processing',
#        'Food and Beverage, Snack Food', 'Automotive, E-Commerce, Mobile',
#        'Computer, Digital Marketing, Facilities Support Services, Graphic Design, Internet, Mobile Apps, Social Media Marketing, Web Development',
#        'Android, Big Data, Blockchain, Cloud Computing, EdTech, Education, Information Technology, iOS, Training, Web Development',
#        'Analytics, CRM, Loyalty Programs, Machine Learning, Marketing Automation, Retail Technology, SaaS, Small and Medium Businesses',
#        'Delivery, Information Technology, Mobile Apps',
#        'Environmental Consulting, Renewable Energy',
#        'Big Data, Business Intelligence, Financial Services, FinTech, Personal Finance',
#        'Commercial Real Estate, Coworking, Office Administration, Real Estate',
#        'Food and Beverage, Food Processing, Organic Food, Snack Food',
#        'Apps, Health Care, Internet, Mobile Apps, Personal Health',
#        'Digital Media, Incubators, Social Entrepreneurship',
#        'Finance, Financial Services, Marketing',
#        'Biotechnology, Health Care, Life Science, Medical Device',
#        'Education, Human Resources', 'Consumer Electronics',
#        'Apps, Health Care, Hospital, Mobile Apps',
#        'Delivery Service, Logistics, Service Industry',
#        'Big Data, Data Visualization, Logistics, Software',
#        'Basketball, Cricket, Cycling, eSports, Fitness, Golf, Health Care, Hockey, Sports, Swimming, Table Tennis, Volley Ball',
#        'Media and Entertainment, News, Publishing', 'Consulting',
#        'Big Data, Financial Services, Machine Learning, Predictive Analytics',
#        'Agriculture, AgTech, Manufacturing',
#        'Digital Media, News, Publishing', 'Health Care, Hospital',
#        'B2B, E-Commerce, Enterprise',
#        'Fraud Detection, Information Services, Security',
#        'Agriculture, AgTech, Artificial Intelligence, Internet of Things, Machine Learning',
#        'Cryptocurrency, Trading Platform',
#        'Finance, FinTech, Mobile Payments', 'Wedding',
#        'E-Learning, EdTech, Education, Image Recognition, Machine Learning, STEM Education',
#        'Consumer Goods', 'Digital Entertainment',
#        'Crowdsourcing, Financial Services, Funding Platform, Venture Capital',
#        'Delivery, Drones, Geospatial, Robotics',
#        'Health Care, Information Technology, Management Information Systems',
#        'Farming',
#        'Business Travel, Hospitality, Hotel, Marketplace, Tourism, Travel Accommodations',
#        'Career Planning, Education, Higher Education, Service Industry',
#        'Medical Device', 'Alternative Medicine, Health Care',
#        'Internet, Software',
#        'Dental, Elder Care, Health Care, Home Health Care, Personal Health',
#        'Financial Services, Insurance, Private Social Networking',
#        'Consumer Electronics, E-Commerce, E-Commerce Platforms, Electronics, Shipping, Shopping',
#        'CleanTech', 'Advertising, Internet, Marketing',
#        'Human Resources, Security, Training',
#        'Consumer Lending, Finance, FinTech',
#        'Marketing, Social Media, Video', 'Banking', 'Food Processing',
#        'Apps', 'Marketing',
#        'Apps, B2B, Freight Service, Logistics, SaaS, Shipping, Supply Chain Management, Transportation',
#        'Digital Entertainment, Fantasy Sports, Gaming, Sports',
#        'Automotive, Last Mile Transportation, Peer to Peer, Ride Sharing',
#        'Commercial, E-Learning, Education',
#        'Continuing Education, EdTech, Education, Skill Assessment',
#        'Smart Cities, Telecommunications', 'Internet of Things, Robotics',
#        'Apps, Home Services, Information Services, Information Technology',
#        'Medical, Tourism', 'Career Planning, Education, Internet',
#        'Fashion, Graphic Design, Wearables',
#        'Communities, Leisure, Mobile Apps, Software',
#        'Automotive, Rental, Sharing Economy',
#        'Energy, Environmental Consulting, Renewable Energy, Solar',
#        'Information Technology, SaaS, Security',
#        'Crowdfunding, Financial Services, Internet',
#        'Customer Service, Information Technology, Internet, Sales Automation',
#        'Advertising, Artificial Intelligence, Digital Media, iOS, Location Based Services, News, Video, Video on Demand, Video Streaming',
#        'Credit Cards, Payments, Property Insurance, Property Management, Rental Property',
#        'Beauty, Cosmetics, Health Care, Service Industry',
#        'EdTech, Education, Mobile, Tutoring', 'Social Media, Sports',
#        'Biopharma', 'E-Commerce, E-Commerce Platforms, Retail',
#        'E-Commerce, Fashion, Shopping',
#        'Digital Entertainment, Mobile, PC Games',
#        'Finance, Financial Services, Small and Medium Businesses',
#        'Artificial Intelligence, Energy, Oil and Gas',
#        'Computer, FinTech, Risk Management, Software',
#        'Apps, Financial Services, FinTech',
#        "Child Care, Health Care, Hospital, Medical, Women's",
#        'Agriculture, Mobile',
#        'Finance, FinTech, Payments, Property Development, Rental',
#        'Information Services, Information Technology, Mobile, Software',
#        'Apps, Fitness, Health Care, mHealth',
#        'Food and Beverage, Food Delivery', 'Apps, Payments, Retail',
#        'Health Insurance, Insurance, Life Insurance',
#        'Rental, Taxi Service, Travel',
#        'E-Commerce, E-Commerce Platforms, Internet, Retail',
#        'Financial Services, Professional Services',
#        'Customer Service, Messaging, Mobile Apps, Personalization',
#        'Gaming, iOS, Sports',
#        'E-Commerce, E-Commerce Platforms, Internet, Mobile Apps, Social Media',
#        'Search Engine',
#        'Battery, Electric Vehicle, Energy, Renewable Energy, Transportation',
#        'Agriculture, Farmers Market, Farming',
#        'Artificial Intelligence, Drones, Navigation, Packaging Services, Robotics',
#        'Fitness, GreenTech, Internet of Things, Mobile Apps, Ride Sharing, Transportation',
#        'Mobile, Software, Travel', 'Cosmetics',
#        'Consulting, Cyber Security, Network Security',
#        'eSports, Gaming, Video Games', 'Fashion, Jewelry',
#        'B2B, Medical Device', 'Consumer Goods, Manufacturing',
#        'Biotechnology, Health Care, Wellness',
#        'Health Care, Hospital, Medical, Robotics',
#        'E-Commerce, Fitness, Health Care',
#        'Financial Services, Venture Capital', 'Accounting, Apps, FinTech',
#        'Apps, Mobile, Transportation', 'Reading Apps',
#        'Energy, Renewable Energy, Solar',
#        'Banking, Financial Services, FinTech', 'Apps, Education, Retail',
#        'Electric Vehicle',
#        'Automotive, Battery, Electric Vehicle, Manufacturing, Mechanical Design',
#        'Automotive, E-Commerce, Marketplace', 'Agriculture',
#        'Apps, Information Services, Information Technology',
#        'B2B, Marketplace', 'Packaging Services',
#        'Computer, Furniture, Software',
#        'Food Delivery, Hospitality, Reservations, Restaurants, Search Engine',
#        'Collaboration, Communities, Coworking, Real Estate',
#        'Accounting, Banking, Finance',
#        'Cloud Computing, Enterprise Software, Network Hardware, Network Security, SaaS',
#        'Information Services, Internet, Logistics, Supply Chain Management, Transportation',
#        'Automotive, E-Commerce, Information Services',
#        'Delivery, Logistics, Transportation',
#        'Automotive, E-Commerce Platforms, Marketplace',
#        'Last Mile Transportation, Railroad, Transportation, Travel',
#        'Cooking, E-Commerce, Food and Beverage, Food Delivery, Online Portals',
#        'FinTech, Mobile, Mobile Payments, Payments, Retail Technology',
#        'Online Games, Software',
#        'Online Portals, Property Management, Rental',
#        'E-Commerce, Food and Beverage, Tea',
#        'Music, Social Network, Video',
#        'Health Care, Pharmaceutical, Wellness',
#        'Delivery Service, Food and Beverage, Food Delivery',
#        'Hospitality, Information Technology, Travel Accommodations',
#        'Biotechnology, Diabetes, Health Care',
#        'Autonomous Vehicles, Last Mile Transportation, Recreational Vehicles, Rental',
#        'Finance, Financial Exchanges, Financial Services, Micro Lending',
#        'Analytics, Apps, Market Research',
#        'E-Commerce, E-Commerce Platforms, Furniture, Home Decor, Internet',
#        'Apps, Mobile, Mobile Apps, Software',
#        'News, Publishing, Social Media',
#        'Industrial, Industrial Automation',
#        'Internet, Mobile Apps, Social Network',
#        'Health Care, Health Diagnostics, Internet of Things, Life Science, Machine Learning, Medical, Medical Device',
#        'E-Commerce, Furniture, Interior Design', 'Apps, Events, News',
#        'Artificial Intelligence, Human Resources, Information Services, Information Technology',
#        'Logistics, Railroad, Transportation',
#        'Dating, Private Social Networking',
#        'Artificial Intelligence, Machine Learning, PaaS',
#        'Consumer, Furniture, Home Decor, Home Improvement',
#        'Apps, E-Commerce, Internet, Mobile, Ride Sharing, Transportation',
#        'Health Care, Health Insurance', 'Energy, Natural Resources',
#        'E-Commerce, Education, Health Care',
#        'Apps, Health Care, Pharmaceutical',
#        'Internet, Knowledge Management',
#        'Credit, Finance, FinTech, Lending, Sales Automation',
#        'Banking, Financial Services, Internet',
#        'E-Commerce, Health Care, Retail',
#        'Child Care, Information Technology',
#        'Financial Services, Micro Lending',
#        'E-Commerce, Retail, Shopping',
#        'Food and Beverage, Snack Food, Tea',
#        'Delivery Service, E-Commerce, Logistics',
#        'Fashion, Lifestyle, Rental', 'Fantasy Sports, Mobile, Sports',
#        'Beauty, Fashion, Wellness', 'Food and Beverage, Restaurants, Tea',
#        'Fitness, Sporting Goods, Sports',
#        'Food and Beverage, Food Processing, Manufacturing',
#        'E-Learning, Internet', 'Eyewear, Internet',
#        'Information Technology, Mobile, News, Operating Systems, Social Media, Social News',
#        'FinTech, Internet, Payments, Service Industry',
#        'B2B, Business Development, Internet, Marketplace',
#        'Food and Beverage, Food Delivery, Internet',
#        'Biotechnology, Health Care, Pharmaceutical'], dtype=object)

# %% [markdown]
# The final 2018 Cleaned Data Set

# %%
data18.head()
# Out:
#    Year    Company/Brand                                             Sector  \
# 0  2018  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  2018  Happy Cow Dairy                               Agriculture, Farming
# 2  2018       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3  2018      PayMe India                        Financial Services, FinTech
# 4  2018         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#       Stage   Amount($) HeadQuarter
# 0      Seed   250000.00   Bengaluru
# 1      Seed   480000.00      Mumbai
# 2  Series A   780000.00     Gurgaon
# 3     Angel  2000000.00       Noida
# 4      Seed 17030531.59   Hyderabad

# %% [markdown]
#   ### 2.2.2 Cleaning the 2019 dataset

# %%
data19.head(10)
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru  2014.00      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane  2014.00     Chennai  Interior design
# 4        Nu Genes  2004.00   Telangana         AgriTech
# 5        FlytBase      NaN        Pune       Technology
# 6           Finly      NaN   Bangalore             SaaS
# 7        Kratikal  2013.00       Noida       Technology
# 8       Quantiphi      NaN         NaN        AI & Tech
# 9        Lenskart  2010.00       Delhi       E-commerce
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
# 5                        A drone automation platform
# 6  It builds software products that makes work si...
# 7  It is a product-based cybersecurity solutions ...
# 8  It is an AI and big data services company prov...
# 9                            It is a eyewear company
#
#                                           Founders  \
# 0                               Shantanu Deshpande
# 1            Adamas Belva Syah Devara, Iman Usman.
# 2                                    Jatin Solanki
# 3                     Srikanth Iyer, Rama Harinath
# 4                           Narayana Reddy Punyala
# 5                                      Nitin Gupta
# 6                        Vivek AG, Veekshith C Rai
# 7  Pavan Kushwaha, Paratosh Bansal, Dip Jung Thapa
# 8                                   Renuka Ramnath
# 9     Peyush Bansal, Amit Chaudhary, Sumeet Kapahi
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
# 5                                        Undisclosed   Undisclosed
# 6  Social Capital, AngelList India, Gemba Capital...   Undisclosed
# 7         Gilda VC, Art Venture, Rajeev Chitrabhanu.    $1,000,000
# 8               Multiples Alternate Asset Management   $20,000,000
# 9                                           SoftBank  $275,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN
# 5            NaN
# 6            NaN
# 7   Pre series A
# 8       Series A
# 9       Series G

# %%
data19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %% [markdown]
# #### I. Dropping columns not needed for analysis

# %%
# Dropping the columns not needed for analysis
columns_to_drop = ['What it does', 'Founded', 'Founders', 'Investor']  #Founded?
data19.drop(columns_to_drop, axis = 1, inplace=True)
data19
# Out:
#       Company/Brand HeadQuarter                   Sector     Amount($)  \
# 0    Bombay Shaving         NaN                Ecommerce    $6,300,000
# 1         Ruangguru      Mumbai                   Edtech  $150,000,000
# 2          Eduisfun      Mumbai                   Edtech   $28,000,000
# 3          HomeLane     Chennai          Interior design   $30,000,000
# 4          Nu Genes   Telangana                 AgriTech    $6,000,000
# ..              ...         ...                      ...           ...
# 84     Infra.Market      Mumbai                Infratech   $20,000,000
# 85              Oyo    Gurugram              Hospitality  $693,000,000
# 86       GoMechanic       Delhi  Automobile & Technology    $5,000,000
# 87           Spinny       Delhi               Automobile   $50,000,000
# 88  Ess Kay Fincorp   Rajasthan                  Banking   $33,000,000
#
#             Stage
# 0             NaN
# 1        Series C
# 2   Fresh funding
# 3        Series D
# 4             NaN
# ..            ...
# 84       Series A
# 85            NaN
# 86       Series B
# 87            NaN
# 88            NaN
#
# [89 rows x 5 columns]

# %% [markdown]
# #### II. Checking for duplicates

# %%
# Check for duplicates
duplicates = data19.duplicated(keep=False)

# Returns the total number of duplicates
duplicates_count = duplicates.value_counts()
duplicates_count
# Out:
# False    89
# dtype: int64

# %% [markdown]
# #### III. Checking for missing values

# %%
# Check for the missing
data19.isnull().sum()
# Out:
# Company/Brand     0
# HeadQuarter      19
# Sector            5
# Amount($)         0
# Stage            46
# dtype: int64

# %% [markdown]
# ##### The aren't many missing values so let's try inspecting them

# %%
# Cleaning the Headquater column
data19['HeadQuarter'].unique()
# Out:
# array([nan, 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bangalore',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan'], dtype=object)

# %%
# Replacing the 'nan' with 'Unknown'
data19['HeadQuarter'] = data19['HeadQuarter'].fillna('Unknown')
data19['HeadQuarter'].unique()
# Out:
# array(['Unknown', 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bangalore',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan'], dtype=object)

# %%
# Cleaning the Sector column
data19['Sector'].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior design', 'AgriTech', 'Technology',
#        'SaaS', 'AI & Tech', 'E-commerce', 'E-commerce & AR', 'Fintech',
#        'HR tech', 'Food tech', 'Health', 'Healthcare', 'Safety tech',
#        'Pharmaceutical', 'Insurance technology', 'AI', 'Foodtech', 'Food',
#        'IoT', 'E-marketplace', 'Robotics & AI', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', nan,
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & tech', 'Accomodation', 'Automotive tech',
#        'Legal tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking'], dtype=object)

# %%
# Replacing nan in Sector column with Unknown
data19['Sector'] = data19['Sector'].fillna('Unknown')
data19
# Out:
#       Company/Brand HeadQuarter                   Sector     Amount($)  \
# 0    Bombay Shaving     Unknown                Ecommerce    $6,300,000
# 1         Ruangguru      Mumbai                   Edtech  $150,000,000
# 2          Eduisfun      Mumbai                   Edtech   $28,000,000
# 3          HomeLane     Chennai          Interior design   $30,000,000
# 4          Nu Genes   Telangana                 AgriTech    $6,000,000
# ..              ...         ...                      ...           ...
# 84     Infra.Market      Mumbai                Infratech   $20,000,000
# 85              Oyo    Gurugram              Hospitality  $693,000,000
# 86       GoMechanic       Delhi  Automobile & Technology    $5,000,000
# 87           Spinny       Delhi               Automobile   $50,000,000
# 88  Ess Kay Fincorp   Rajasthan                  Banking   $33,000,000
#
#             Stage
# 0             NaN
# 1        Series C
# 2   Fresh funding
# 3        Series D
# 4             NaN
# ..            ...
# 84       Series A
# 85            NaN
# 86       Series B
# 87            NaN
# 88            NaN
#
# [89 rows x 5 columns]

# %% [markdown]
# For stage column lets fill it with the mode entry to maintain data quality and avoid bias analysis

# %%
#Lets check for unique values in stage column
data19['Stage'].value_counts(ascending= False)
# Out:
# Series A         10
# Pre series A      8
# Series B          8
# Series D          4
# Series C          3
# Fresh funding     1
# Series G          1
# Post series A     1
# Seed funding      1
# Seed fund         1
# Series E          1
# Series F          1
# Series B+         1
# Seed round        1
# Pre-series A      1
# Name: Stage, dtype: int64

# %%
# Calculate the mode value for the 'Stage' column, the missing values are a few
mode_stage = data19['Stage'].mode().iloc[0]

# Fill the missing values in the 'Stage' column with the mode value
data19['Stage'].fillna(mode_stage, inplace=True)

# %%
# lets check if the missing value has been replaced with the mode
data19['Stage'].value_counts(ascending= False)
# Out:
# Series A         56
# Pre series A      8
# Series B          8
# Series D          4
# Series C          3
# Fresh funding     1
# Series G          1
# Post series A     1
# Seed funding      1
# Seed fund         1
# Series E          1
# Series F          1
# Series B+         1
# Seed round        1
# Pre-series A      1
# Name: Stage, dtype: int64

# %% [markdown]
# Inspecting Amount Column

# %%
data19['Amount($)'].value_counts()
# Out:
# Undisclosed     12
# $5,000,000       6
# $1,500,000       4
# $6,000,000       4
# $1,000,000       4
# $30,000,000      3
# $20,000,000      3
# $50,000,000      3
# $4,000,000       3
# $5,500,000       3
# $26,000,000      2
# $2,000,000       2
# $12,000,000      2
# $100,000         2
# $5,700,000       1
# $693,000,000     1
# $4,800,000       1
# $120,000,000     1
# $311,000,000     1
# $6,800,000       1
# $36,000,000      1
# $2,800,000       1
# $220,000         1
# $600,000         1
# $7,000,000       1
# $2,100,000       1
# $70,000,000      1
# $60,000,000      1
# $8,000,000       1
# $25,000,000      1
# $6,300,000       1
# $100,000,000     1
# $11,000,000      1
# $28,000,000      1
# $275,000,000     1
# $22,000,000      1
# $140,500         1
# $540,000,000     1
# $15,000,000      1
# $182,700         1
# $15,500,000      1
# $400,000         1
# $2,500,000       1
# $140,000         1
# $230,000,000     1
# $49,400,000      1
# $32,000,000      1
# $150,000,000     1
# $150,000         1
# $33,000,000      1
# Name: Amount($), dtype: int64

# %%
# Cleaning the amount column
# Replace currency symbol and commas with empty string
data19['Amount($)'] = data19['Amount($)'].str.replace(',', '', regex=False).str.replace('$', '', regex=False)

# Convert 'Amount' column to numeric datatype, replacing any non-numeric values.
data19['Amount($)'] = pd.to_numeric(data19['Amount($)'], errors='coerce')

# Convert Amount($) column from object to float datatype
data19['Amount($)'] = data19['Amount($)'].astype(float)

# The updated dataframe
data19.head(10)
# Out:
#     Company/Brand HeadQuarter           Sector    Amount($)          Stage
# 0  Bombay Shaving     Unknown        Ecommerce   6300000.00       Series A
# 1       Ruangguru      Mumbai           Edtech 150000000.00       Series C
# 2        Eduisfun      Mumbai           Edtech  28000000.00  Fresh funding
# 3        HomeLane     Chennai  Interior design  30000000.00       Series D
# 4        Nu Genes   Telangana         AgriTech   6000000.00       Series A
# 5        FlytBase        Pune       Technology          NaN       Series A
# 6           Finly   Bangalore             SaaS          NaN       Series A
# 7        Kratikal       Noida       Technology   1000000.00   Pre series A
# 8       Quantiphi     Unknown        AI & Tech  20000000.00       Series A
# 9        Lenskart       Delhi       E-commerce 275000000.00       Series G

# %%
# Replace NaN values in 'Amount($)' column with the mean
# Calculate the mean of Amount
median_amount = data19['Amount($)'].median()

# Replace NaN values with mean
data19['Amount($)'].fillna(median_amount, inplace=True)
data19.head(10)
# Out:
#     Company/Brand HeadQuarter           Sector    Amount($)          Stage
# 0  Bombay Shaving     Unknown        Ecommerce   6300000.00       Series A
# 1       Ruangguru      Mumbai           Edtech 150000000.00       Series C
# 2        Eduisfun      Mumbai           Edtech  28000000.00  Fresh funding
# 3        HomeLane     Chennai  Interior design  30000000.00       Series D
# 4        Nu Genes   Telangana         AgriTech   6000000.00       Series A
# 5        FlytBase        Pune       Technology   6000000.00       Series A
# 6           Finly   Bangalore             SaaS   6000000.00       Series A
# 7        Kratikal       Noida       Technology   1000000.00   Pre series A
# 8       Quantiphi     Unknown        AI & Tech  20000000.00       Series A
# 9        Lenskart       Delhi       E-commerce 275000000.00       Series G

# %%
# Check for missing values 
data19.isna().sum()
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# Stage            0
# dtype: int64

# %%
#Inspecting stage column
data19['Stage'].unique()
# Out:
# array(['Series A', 'Series C', 'Fresh funding', 'Series D',
#        'Pre series A', 'Series G', 'Series B', 'Post series A',
#        'Seed funding', 'Seed fund', 'Series E', 'Series F', 'Series B+',
#        'Seed round', 'Pre-series A'], dtype=object)

# %%
# Creating a year column and filling with 2019
data19.insert(0,'Year', 2019)
data19.head()
# Out:
#    Year   Company/Brand HeadQuarter           Sector    Amount($)  \
# 0  2019  Bombay Shaving     Unknown        Ecommerce   6300000.00
# 1  2019       Ruangguru      Mumbai           Edtech 150000000.00
# 2  2019        Eduisfun      Mumbai           Edtech  28000000.00
# 3  2019        HomeLane     Chennai  Interior design  30000000.00
# 4  2019        Nu Genes   Telangana         AgriTech   6000000.00
#
#            Stage
# 0       Series A
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4       Series A

# %%
#rearrange columns to conform with other datasets
# Create a list of column names in the desired order
desired_columns = ['Year', 'Company/Brand', 'Sector', 'Amount($)', 'Stage', 'HeadQuarter']

# Reindex the DataFrame with the desired column order
data19 = data19.reindex(columns=desired_columns)

# %% [markdown]
# The final Cleaned 2019 DATA SET

# %%
data19.head(10)
# Out:
#    Year   Company/Brand           Sector    Amount($)          Stage  \
# 0  2019  Bombay Shaving        Ecommerce   6300000.00       Series A
# 1  2019       Ruangguru           Edtech 150000000.00       Series C
# 2  2019        Eduisfun           Edtech  28000000.00  Fresh funding
# 3  2019        HomeLane  Interior design  30000000.00       Series D
# 4  2019        Nu Genes         AgriTech   6000000.00       Series A
# 5  2019        FlytBase       Technology   6000000.00       Series A
# 6  2019           Finly             SaaS   6000000.00       Series A
# 7  2019        Kratikal       Technology   1000000.00   Pre series A
# 8  2019       Quantiphi        AI & Tech  20000000.00       Series A
# 9  2019        Lenskart       E-commerce 275000000.00       Series G
#
#   HeadQuarter
# 0     Unknown
# 1      Mumbai
# 2      Mumbai
# 3     Chennai
# 4   Telangana
# 5        Pune
# 6   Bangalore
# 7       Noida
# 8     Unknown
# 9       Delhi

# %% [markdown]
#   #### 2.2.3. Cleaning 2020 Dataset

# %%
#cleaning the 2020 data
data20.head(10)
# Out:
#   Company_Brand  Founded HeadQuarter               Sector  \
# 0    Aqgromalin  2019.00     Chennai             AgriTech
# 1      Krayonnz  2019.00   Bangalore               EdTech
# 2  PadCare Labs  2018.00        Pune   Hygiene management
# 3         NCOME  2020.00   New Delhi               Escrow
# 4    Gramophone  2016.00      Indore             AgriTech
# 5        qZense  2019.00   Bangalore             AgriTech
# 6  MyClassboard  2008.00   Hyderabad               EdTech
# 7         Metvy  2018.00     Gurgaon  Networking platform
# 8        Rupeek  2015.00   Bangalore              FinTech
# 9     Gig India  2017.00        Pune        Crowdsourcing
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
# 5  qZense Labs is building the next-generation Io...
# 6  MyClassboard is a full-fledged School / Colleg...
# 7  AI driven networking platform for individuals ...
# 8  Rupeek is an online lending platform that spec...
# 9  GigIndia is a marketplace that provides on-dem...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# 5                       Rubal Chib, Dr Srishti Batra
# 6                                     Ajay Sakhamuri
# 7                                   Shawrya Mehrotra
# 8            Amar Prabhu, Ashwin Soni, Sumit Maniyar
# 9                       Aditya Shirole, Sahil Sharma
#
#                                         Investor      Amount         Stage  \
# 0                                Angel investors   200000.00          None
# 1                                GSF Accelerator   100000.00      Pre-seed
# 2                                 Venture Center         NaN      Pre-seed
# 3            Venture Catalysts, PointOne Capital   400000.00          None
# 4            Siana Capital Management, Info Edge   340000.00          None
# 5  Venture Catalysts, 9Unicorns Accelerator Fund   600000.00          Seed
# 6                                    ICICI Bank.   600000.00  Pre-series A
# 7                                     HostelFund         NaN    Pre-series
# 8   KB Investment, Bertelsmann India Investments 45000000.00      Series C
# 9      Shantanu Deshpande, Subramaniam Ramadorai  1000000.00  Pre-series A
#
#   column10
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None

# %%
## check for Data Types
data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.5+ KB

# %%
# Check for shape of the data
data20.shape
# Out:
# (1055, 10)

# %% [markdown]
# The data 2020 has 10 columns, where by two of the columns contains float entries and 8 others contains object entries

# %% [markdown]
#  I. Drop columns not needed for analysis

# %%
#drop column 10,founders,investor,what it does,Founded, since it is needed for analysis
data20 = data20.drop('column10', axis=1)
data20 = data20.drop('Founders', axis=1)
data20 = data20.drop('Investor', axis = 1)
data20 = data20.drop('What_it_does', axis = 1)
data20 = data20.drop('Founded',axis = 1)

# %%
data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   HeadQuarter    961 non-null    object
#  2   Sector         1042 non-null   object
#  3   Amount         801 non-null    float64
#  4   Stage          591 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 41.3+ KB

# %% [markdown]
# The unnecessary columns have been dropped and now we have 5 columns left. Lets rename the columns to match with 2018 and 2019 data

# %%
#rename column names to make it consistent with the other data set
data20.rename(columns={'Company_Brand' : 'Company/Brand'}, inplace = True)

# %%
#The updated Dataframe for 2020
data20.head(10)
# Out:
#   Company/Brand HeadQuarter               Sector      Amount         Stage
# 0    Aqgromalin     Chennai             AgriTech   200000.00          None
# 1      Krayonnz   Bangalore               EdTech   100000.00      Pre-seed
# 2  PadCare Labs        Pune   Hygiene management         NaN      Pre-seed
# 3         NCOME   New Delhi               Escrow   400000.00          None
# 4    Gramophone      Indore             AgriTech   340000.00          None
# 5        qZense   Bangalore             AgriTech   600000.00          Seed
# 6  MyClassboard   Hyderabad               EdTech   600000.00  Pre-series A
# 7         Metvy     Gurgaon  Networking platform         NaN    Pre-series
# 8        Rupeek   Bangalore              FinTech 45000000.00      Series C
# 9     Gig India        Pune        Crowdsourcing  1000000.00  Pre-series A

# %% [markdown]
#  II. Check for duplicates in the data set

# %%
#check for duplicates in the data20
duplicates = data20.duplicated(keep=False)

#returns the total number of duplicates
duplicates_count = duplicates.value_counts()
duplicates_count
# Out:
# False    1043
# True       12
# dtype: int64

# %%
#identify docuplicated rows
duplicates = data20[data20.duplicated(keep=False)]
duplicates
# Out:
#        Company/Brand HeadQuarter                 Sector       Amount Stage
# 120            Nykaa      Mumbai              Cosmetics          NaN  None
# 129        Krimanshi     Jodhpur  Biotechnology company    600000.00  Seed
# 145        Krimanshi     Jodhpur  Biotechnology company    600000.00  Seed
# 205            Nykaa      Mumbai              Cosmetics          NaN  None
# 215   Genius Teacher      Mumbai                 Edtech   2000000.00  None
# 233   Genius Teacher      Mumbai                 Edtech   2000000.00  None
# 326           Byju’s   Bangalore                 EdTech 500000000.00  None
# 362           Byju’s   Bangalore                 EdTech 500000000.00  None
# 771    Capital Float   Bangalore                Fintech  15000000.00  None
# 935             Byju        None                 Edtech 200000000.00  None
# 1014   Capital Float   Bangalore                Fintech  15000000.00  None
# 1035            Byju        None                 Edtech 200000000.00  None

# %%
#There are 12 duplicated rows
#drop duplicated rows
data20.drop_duplicates(keep='first', inplace= True)

# %%
#check if duplicates have been dropped
duplicates = data20[data20.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Company/Brand, HeadQuarter, Sector, Amount, Stage]
# Index: []

# %% [markdown]
# III. Check for missing values

# %%
#checking for missing values in Data20
missing_values_data20 = data20.isnull().sum()
missing_values_data20
# Out:
# Company/Brand      0
# HeadQuarter       93
# Sector            13
# Amount           253
# Stage            459
# dtype: int64

# %% [markdown]
# Handling Missing values columnwise- inspecting sector column

# %%
## Inspect the company column,
data20['Sector'].value_counts()
# Out:
# Fintech                  79
# Edtech                   65
# FinTech                  51
# EdTech                   39
# E-commerce               33
#                          ..
# Jewellery                 1
# AR startup                1
# HR Tech startup           1
# Automotive Startup        1
# Automobile Technology     1
# Name: Sector, Length: 302, dtype: int64

# %%
#replace missing values in 'Sector' column with 'Unknown'
data20['Sector'] = data20['Sector'].fillna('Unknown')
data20.head(10)
# Out:
#   Company/Brand HeadQuarter               Sector      Amount         Stage
# 0    Aqgromalin     Chennai             AgriTech   200000.00          None
# 1      Krayonnz   Bangalore               EdTech   100000.00      Pre-seed
# 2  PadCare Labs        Pune   Hygiene management         NaN      Pre-seed
# 3         NCOME   New Delhi               Escrow   400000.00          None
# 4    Gramophone      Indore             AgriTech   340000.00          None
# 5        qZense   Bangalore             AgriTech   600000.00          Seed
# 6  MyClassboard   Hyderabad               EdTech   600000.00  Pre-series A
# 7         Metvy     Gurgaon  Networking platform         NaN    Pre-series
# 8        Rupeek   Bangalore              FinTech 45000000.00      Series C
# 9     Gig India        Pune        Crowdsourcing  1000000.00  Pre-series A

# %% [markdown]
# Inspecting the Amount column

# %%
## Inspect the company column,
data20['Amount'].unique()
# Out:
# array([2.0000000e+05, 1.0000000e+05,           nan, 4.0000000e+05,
#        3.4000000e+05, 6.0000000e+05, 4.5000000e+07, 1.0000000e+06,
#        2.0000000e+06, 1.2000000e+06, 6.6000000e+08, 1.2000000e+05,
#        7.5000000e+06, 5.0000000e+06, 5.0000000e+05, 3.0000000e+06,
#        1.0000000e+07, 1.4500000e+08, 1.0000000e+08, 2.1000000e+07,
#        4.0000000e+06, 2.0000000e+07, 5.6000000e+05, 2.7500000e+05,
#        4.5000000e+06, 1.5000000e+07, 3.9000000e+08, 7.0000000e+06,
#        5.1000000e+06, 7.0000000e+08, 2.3000000e+06, 7.0000000e+05,
#        1.9000000e+07, 9.0000000e+06, 4.0000000e+07, 7.5000000e+05,
#        1.5000000e+06, 7.8000000e+06, 5.0000000e+07, 8.0000000e+07,
#        3.0000000e+07, 1.7000000e+06, 2.5000000e+06, 4.0000000e+04,
#        3.3000000e+07, 3.5000000e+07, 3.0000000e+05, 2.5000000e+07,
#        3.5000000e+06, 2.0000000e+08, 6.0000000e+06, 1.3000000e+06,
#        4.1000000e+06, 5.7500000e+05, 8.0000000e+05, 2.8000000e+07,
#        1.8000000e+07, 3.2000000e+06, 9.0000000e+05, 2.5000000e+05,
#        4.7000000e+06, 7.5000000e+07, 8.0000000e+06, 1.2100000e+08,
#        5.5000000e+07, 3.3000000e+06, 1.1000000e+07, 1.6000000e+07,
#        5.4000000e+06, 1.5000000e+08, 4.2000000e+06, 2.2000000e+07,
#        5.2000000e+07, 1.1000000e+06, 1.1800000e+08, 1.6000000e+06,
#        1.8500000e+07, 7.0000000e+10, 8.0000000e+08, 4.0000000e+08,
#        1.5000000e+05, 1.7600000e+08, 6.0000000e+07, 4.7000000e+05,
#        2.4000000e+05, 3.0000000e+09, 7.4000000e+07, 6.2000000e+07,
#        2.1000000e+06, 5.0000000e+08, 1.2500000e+07, 2.2000000e+09,
#        5.0600000e+06, 2.2500000e+08, 2.4700000e+07, 7.7000000e+06,
#        1.9067328e+07, 5.1000000e+07, 1.1500000e+05, 5.4000000e+04,
#        2.0000000e+04, 8.0314600e+05, 2.3800000e+05, 1.0220000e+07,
#        1.0200000e+06, 1.2000000e+07, 1.3400000e+07, 1.7000000e+08,
#        2.9000000e+06, 5.4300000e+05, 9.0000000e+07, 3.4000000e+06,
#        2.3000000e+07, 8.0900000e+06, 1.0300000e+06, 5.0400000e+06,
#        3.6000000e+05, 1.4000000e+06, 6.5000000e+05, 5.4000000e+07,
#        4.2500000e+07, 1.1370000e+07, 3.2500000e+05, 4.1000000e+05,
#        4.5000000e+05, 6.8200000e+05, 4.0500000e+06, 1.0500000e+06,
#        1.0800000e+06, 4.3000000e+06, 6.8000000e+06, 2.1100000e+06,
#        7.6400000e+05, 6.0300000e+05, 4.0900000e+05, 2.9200000e+05,
#        2.8600000e+05, 1.3600000e+05, 5.4600000e+05, 8.8700000e+05,
#        4.3000000e+04, 4.0900000e+04, 2.2000000e+06, 5.6600000e+06,
#        3.5000000e+05, 1.1000000e+05, 1.2200000e+08, 1.1635000e+07,
#        2.8000000e+06, 1.0650000e+06, 6.6900000e+05, 1.6076000e+07,
#        6.4960000e+05, 6.7000000e+06, 2.2000000e+05, 2.6650000e+05,
#        2.8790000e+06, 2.6500000e+07, 3.5100000e+05, 4.6761000e+07,
#        1.7500000e+05, 1.1241000e+07, 8.0400000e+05, 1.3400000e+06,
#        4.6700000e+05, 1.3300000e+05, 3.8230000e+06, 9.3400000e+05,
#        2.9300000e+05, 1.9800000e+05, 9.2700000e+05, 9.7100000e+05,
#        3.0600000e+06, 1.8620000e+06, 2.3200000e+05, 2.8880000e+06,
#        1.3280000e+06, 1.5500000e+07, 5.6000000e+07, 2.2500000e+06,
#        1.6753000e+07, 3.7000000e+06, 1.4700000e+06, 5.3000000e+05,
#        2.6700000e+05, 3.3440000e+06, 7.2000000e+06, 2.7430000e+06,
#        6.0820000e+06, 6.6090000e+06, 2.7700000e+07, 5.9400000e+06,
#        3.9640000e+06, 5.5000000e+06, 1.9700000e+05, 4.3270000e+06,
#        4.5900000e+05, 3.9370000e+06, 1.3135000e+06, 2.2980000e+05,
#        5.3050000e+06, 2.6400000e+05, 1.7500000e+06, 5.9670000e+06,
#        2.9800000e+06, 3.2300000e+05, 1.3260000e+06, 2.7000000e+07,
#        5.2000000e+06, 2.5300000e+06, 7.9200000e+05, 1.1363000e+07,
#        1.7150000e+06, 3.2900000e+05, 5.2710000e+06, 8.7000000e+06,
#        3.2260000e+06, 5.9000000e+06, 4.4000000e+07, 3.8790000e+06,
#        1.3000000e+07, 8.8000000e+06, 9.5000000e+06, 9.2000000e+05,
#        3.5600000e+07, 9.4000000e+06, 7.9000000e+05, 4.8000000e+05,
#        1.6000000e+05, 8.2000000e+06, 4.2570000e+06, 1.4100000e+06,
#        3.4980000e+05, 7.8600000e+05, 2.0040000e+06, 1.2300000e+08,
#        2.4800000e+05, 2.4000000e+07, 1.4259000e+07, 2.4500000e+07,
#        3.8000000e+06, 1.8370000e+07, 6.8525000e+07, 4.8000000e+06,
#        1.8340000e+06, 2.3850000e+07, 4.3000000e+07, 2.1600000e+07,
#        4.5980000e+06, 1.3137000e+07, 1.1500000e+08, 3.9000000e+06,
#        6.7000000e+05, 8.5000000e+06, 3.1480000e+06, 2.6000000e+06,
#        4.0495000e+06, 1.0500000e+07, 6.5000000e+06, 4.3700000e+07,
#        1.3800000e+07, 3.0690000e+05, 4.2000000e+05, 6.2730000e+05,
#        1.1300000e+08, 3.2000000e+07, 1.1000000e+08, 1.3970000e+06,
#        4.4850000e+05, 7.9757000e+06, 3.3000000e+05, 5.6000000e+06,
#        1.4020000e+06, 2.1500000e+07, 2.9600000e+08, 4.9000000e+06,
#        1.4024000e+06, 1.2618300e+07, 9.9000000e+06, 9.8253000e+05,
#        7.0185200e+07, 2.1000000e+08, 8.4000000e+07, 3.9000000e+07,
#        2.7000000e+06, 1.4034000e+06, 1.0500000e+08, 1.0300000e+08,
#        2.8130000e+05, 1.2700000e+04, 2.5000000e+04, 9.7500000e+07,
#        5.0700000e+05, 8.4000000e+06, 1.8300000e+07, 1.2500000e+08,
#        1.8100000e+05, 2.8000000e+05, 1.4700000e+07, 1.3200000e+07,
#        8.0430000e+06])

# %%
#It is assumed that the amounts are already in dollars.
#Rename 'Amount' column to 'Amount($)'
data20.rename(columns={'Amount' : 'Amount($)'}, inplace= True)
data20
# Out:
#      Company/Brand HeadQuarter              Sector   Amount($)       Stage
# 0       Aqgromalin     Chennai            AgriTech   200000.00        None
# 1         Krayonnz   Bangalore              EdTech   100000.00    Pre-seed
# 2     PadCare Labs        Pune  Hygiene management         NaN    Pre-seed
# 3            NCOME   New Delhi              Escrow   400000.00        None
# 4       Gramophone      Indore            AgriTech   340000.00        None
# ...            ...         ...                 ...         ...         ...
# 1050  Leverage Edu       Delhi              Edtech  1500000.00        None
# 1051         EpiFi        None             Fintech 13200000.00  Seed Round
# 1052       Purplle      Mumbai           Cosmetics  8000000.00        None
# 1053        Shuttl       Delhi           Transport  8043000.00    Series C
# 1054         Pando     Chennai            Logitech  9000000.00    Series A
#
# [1049 rows x 5 columns]

# %%
#calculate mean of the 'Amount($)' column 
#Replace missing values in 'Amount($)' column with the median
median_value = data20['Amount($)'].median()

data20['Amount($)'].fillna(value = median_value,  inplace=True)

data20
# Out:
#      Company/Brand HeadQuarter              Sector   Amount($)       Stage
# 0       Aqgromalin     Chennai            AgriTech   200000.00        None
# 1         Krayonnz   Bangalore              EdTech   100000.00    Pre-seed
# 2     PadCare Labs        Pune  Hygiene management  3000000.00    Pre-seed
# 3            NCOME   New Delhi              Escrow   400000.00        None
# 4       Gramophone      Indore            AgriTech   340000.00        None
# ...            ...         ...                 ...         ...         ...
# 1050  Leverage Edu       Delhi              Edtech  1500000.00        None
# 1051         EpiFi        None             Fintech 13200000.00  Seed Round
# 1052       Purplle      Mumbai           Cosmetics  8000000.00        None
# 1053        Shuttl       Delhi           Transport  8043000.00    Series C
# 1054         Pando     Chennai            Logitech  9000000.00    Series A
#
# [1049 rows x 5 columns]

# %% [markdown]
# Inspecting Stage column to check abnormly

# %%
## Inspect the stage column,
data20['Stage'].value_counts(ascending=False)
# Out:
# Series A                 96
# Seed                     79
# Seed Round               69
# Series B                 57
# Pre series A             54
# Pre-series A             53
# Series C                 50
# Series D                 22
# Debt                     18
# Pre Series A             12
# Pre-seed                 11
# Seed round                9
# Series E                  6
# Bridge                    6
# Series F                  4
# Pre-series B              4
# Angel Round               4
# Pre seed round            4
# Pre-seed Round            2
# Pre series B              2
# Pre-Seed                  2
# Seed Funding              2
# Series B2                 2
# Pre-series C              2
# Seed funding              2
# Pre-Series B              2
# Seed Round & Series A     1
# Series C, D               1
# Mid series                1
# Series D1                 1
# Seed Investment           1
# Pre series C              1
# Pre-series                1
# Bridge Round              1
# Series H                  1
# Seed A                    1
# Pre- series A             1
# Series E2                 1
# Pre series A1             1
# Edge                      1
# Pre seed Round            1
# Series A-1                1
# Name: Stage, dtype: int64

# %%
# Fill the missing values in the 'Stage' column with the mode entry of that coln 
# Calculate the mode value for the 'Stage' column
mode_stage20 = data20['Stage'].mode().iloc[0]

# Fill the missing values in the 'Stage' column with the mode value
data20['Stage'].fillna(mode_stage20, inplace=True)
data20.head(10)
# Out:
#   Company/Brand HeadQuarter               Sector   Amount($)         Stage
# 0    Aqgromalin     Chennai             AgriTech   200000.00      Series A
# 1      Krayonnz   Bangalore               EdTech   100000.00      Pre-seed
# 2  PadCare Labs        Pune   Hygiene management  3000000.00      Pre-seed
# 3         NCOME   New Delhi               Escrow   400000.00      Series A
# 4    Gramophone      Indore             AgriTech   340000.00      Series A
# 5        qZense   Bangalore             AgriTech   600000.00          Seed
# 6  MyClassboard   Hyderabad               EdTech   600000.00  Pre-series A
# 7         Metvy     Gurgaon  Networking platform  3000000.00    Pre-series
# 8        Rupeek   Bangalore              FinTech 45000000.00      Series C
# 9     Gig India        Pune        Crowdsourcing  1000000.00  Pre-series A

# %% [markdown]
# IV. Inspecting  columns for anomaly

# %%
#Inspect the HeadQuarter column,
data20['HeadQuarter'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli, Tamilnadu', 'Thane', None,
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'Jaipur, Rajastan', 'Delhi', 'Frisco, Texas, United States',
#        'California', 'Dhingsara, Haryana', 'New York, United States',
#        'Patna', 'San Francisco, California, United States',
#        'San Francisco, United States', 'San Ramon, California',
#        'Paris, Ile-de-France, France', 'Plano, Texas, United States',
#        'Sydney', 'San Francisco Bay Area, Silicon Valley, West Coast',
#        'Bangaldesh', 'London, England, United Kingdom',
#        'Sydney, New South Wales, Australia', 'Milano, Lombardia, Italy',
#        'Palmwoods, Queensland, Australia', 'France',
#        'San Francisco Bay Area, West Coast, Western US',
#        'Trivandrum, Kerala, India', 'Cochin', 'Samastipur, Bihar',
#        'Irvine, California, United States', 'Tumkur, Karnataka',
#        'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#        'Shanghai, China', 'Jiaxing, Zhejiang, China', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'San Francisco',
#        'Tangerang, Jawa Barat, Indonesia', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'New York', 'Bangkok', 'Kanpur', 'Chandigarh', 'Warangal',
#        'Hyderebad', 'Odisha', 'Bihar', 'Goa', 'Tamil Nadu',
#        'Uttar Pradesh', 'Bhopal', 'Banglore', 'Coimbatore', 'Bengaluru'],
#       dtype=object)

# %%
data20[["City", "State", "Country"]]= data20['HeadQuarter'].str.split(',', expand=True)
data20.tail(30)
# Out:
#           Company/Brand HeadQuarter                 Sector    Amount($)  \
# 1024  Harappa Education   New Delhi                 Edtech   3000000.00
# 1025               Rheo        None          Entertainment   2000000.00
# 1026  Axio Biosolutions   Bangalore                Medtech   5200000.00
# 1027          Techbooze        None            Consultancy  15000000.00
# 1028            PayMart  Chandigarh                Fintech   3000000.00
# 1029           Testbook        None                 Edtech   8400000.00
# 1030           FabAlley       Noida              Ecommerce   1100000.00
# 1031           HaikuJAM        None                Unknown   3400000.00
# 1032          Mamaearth        None              Ecommerce  18300000.00
# 1033          Rentomojo        None                 Rental   2000000.00
# 1034             Zomato        None               Foodtech 150000000.00
# 1036           Generico      Mumbai               Pharmacy   1400000.00
# 1037         HighRadius   Hyderabad                   SaaS 125000000.00
# 1038         Chai Kings     Chennai               Beverage   1000000.00
# 1039             Rivigo    Gurugram              Logistics   3400000.00
# 1040           BuildPan      Indore                   SaaS   3000000.00
# 1041            Shiksha        None                 Edtech    181000.00
# 1042     Super Surfaces   Hyderabad              Deisgning    500000.00
# 1043             Quicko   Ahmedabad               Taxation    280000.00
# 1044   Satin Creditcare     Gurgaon                Fintech  15000000.00
# 1045         XpressBees        None              Logistics  10000000.00
# 1046            FarmERP        Pune               Agritech   3000000.00
# 1047      Wealth Bucket        None                Fintech   3000000.00
# 1048         GoMechanic       Delhi  Automobile Technology  14700000.00
# 1049             Fashor     Chennai                Fashion   1000000.00
# 1050       Leverage Edu       Delhi                 Edtech   1500000.00
# 1051              EpiFi        None                Fintech  13200000.00
# 1052            Purplle      Mumbai              Cosmetics   8000000.00
# 1053             Shuttl       Delhi              Transport   8043000.00
# 1054              Pando     Chennai               Logitech   9000000.00
#
#              Stage        City State Country
# 1024      Series A   New Delhi  None    None
# 1025      Series A        None  None    None
# 1026      Series B   Bangalore  None    None
# 1027      Series A        None  None    None
# 1028      Series A  Chandigarh  None    None
# 1029      Series B        None  None    None
# 1030      Series A       Noida  None    None
# 1031      Series A        None  None    None
# 1032      Series A        None  None    None
# 1033      Series A        None  None    None
# 1034      Series A        None  None    None
# 1036      Series A      Mumbai  None    None
# 1037      Series B   Hyderabad  None    None
# 1038      Series A     Chennai  None    None
# 1039      Series F    Gurugram  None    None
# 1040    Seed Round      Indore  None    None
# 1041      Series A        None  None    None
# 1042      Series A   Hyderabad  None    None
# 1043      Series A   Ahmedabad  None    None
# 1044      Series A     Gurgaon  None    None
# 1045      Series A        None  None    None
# 1046      Series A        Pune  None    None
# 1047      Series A        None  None    None
# 1048      Series B       Delhi  None    None
# 1049  Pre Series A     Chennai  None    None
# 1050      Series A       Delhi  None    None
# 1051    Seed Round        None  None    None
# 1052      Series A      Mumbai  None    None
# 1053      Series C       Delhi  None    None
# 1054      Series A     Chennai  None    None

# %%
data20['State'].unique()
# Out:
# array([None, ' Tamilnadu', ' Rajastan', ' Texas', ' Haryana',
#        ' United States', ' California', ' Ile-de-France',
#        ' Silicon Valley', ' England', ' New South Wales', ' Lombardia',
#        ' Queensland', ' West Coast', ' Kerala', ' Bihar', ' Karnataka',
#        ' Newcastle upon Tyne', ' China', ' Zhejiang', ' Jawa Barat'],
#       dtype=object)

# %%
# Drop Columns named - State Country and Hedquater then name city headquater

data20.drop('Country',axis = 1,inplace = True)
data20.drop('State',axis = 1,inplace = True)
data20.drop('HeadQuarter',axis = 1,inplace = True)
data20.head()
# Out:
#   Company/Brand              Sector  Amount($)     Stage       City
# 0    Aqgromalin            AgriTech  200000.00  Series A    Chennai
# 1      Krayonnz              EdTech  100000.00  Pre-seed  Bangalore
# 2  PadCare Labs  Hygiene management 3000000.00  Pre-seed       Pune
# 3         NCOME              Escrow  400000.00  Series A  New Delhi
# 4    Gramophone            AgriTech  340000.00  Series A     Indore

# %%
#replace missing values in 'Location' column with 'Unknown'
data20['City'] = data20['City'].fillna('Unknown')
data20.tail(20)
# Out:
#          Company/Brand                 Sector    Amount($)         Stage  \
# 1034            Zomato               Foodtech 150000000.00      Series A
# 1036          Generico               Pharmacy   1400000.00      Series A
# 1037        HighRadius                   SaaS 125000000.00      Series B
# 1038        Chai Kings               Beverage   1000000.00      Series A
# 1039            Rivigo              Logistics   3400000.00      Series F
# 1040          BuildPan                   SaaS   3000000.00    Seed Round
# 1041           Shiksha                 Edtech    181000.00      Series A
# 1042    Super Surfaces              Deisgning    500000.00      Series A
# 1043            Quicko               Taxation    280000.00      Series A
# 1044  Satin Creditcare                Fintech  15000000.00      Series A
# 1045        XpressBees              Logistics  10000000.00      Series A
# 1046           FarmERP               Agritech   3000000.00      Series A
# 1047     Wealth Bucket                Fintech   3000000.00      Series A
# 1048        GoMechanic  Automobile Technology  14700000.00      Series B
# 1049            Fashor                Fashion   1000000.00  Pre Series A
# 1050      Leverage Edu                 Edtech   1500000.00      Series A
# 1051             EpiFi                Fintech  13200000.00    Seed Round
# 1052           Purplle              Cosmetics   8000000.00      Series A
# 1053            Shuttl              Transport   8043000.00      Series C
# 1054             Pando               Logitech   9000000.00      Series A
#
#            City
# 1034    Unknown
# 1036     Mumbai
# 1037  Hyderabad
# 1038    Chennai
# 1039   Gurugram
# 1040     Indore
# 1041    Unknown
# 1042  Hyderabad
# 1043  Ahmedabad
# 1044    Gurgaon
# 1045    Unknown
# 1046       Pune
# 1047    Unknown
# 1048      Delhi
# 1049    Chennai
# 1050      Delhi
# 1051    Unknown
# 1052     Mumbai
# 1053      Delhi
# 1054    Chennai

# %%
# Rename City column to Headquarter
data20.rename(columns={'City':'HeadQuarter'}, inplace=True)

# %% [markdown]
# Confirm if missing values have been resolved

# %%
#check for missing values
data20.isna().sum()
# Out:
# Company/Brand    0
# Sector           0
# Amount($)        0
# Stage            0
# HeadQuarter      0
# dtype: int64

# %%
## Inspect the company column,
data20['HeadQuarter'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli', 'Thane', 'Unknown',
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'Delhi', 'Frisco', 'California', 'Dhingsara', 'New York', 'Patna',
#        'San Francisco', 'San Ramon', 'Paris', 'Plano', 'Sydney',
#        'San Francisco Bay Area', 'Bangaldesh', 'London', 'Milano',
#        'Palmwoods', 'France', 'Trivandrum', 'Cochin', 'Samastipur',
#        'Irvine', 'Tumkur', 'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing',
#        'Rajastan', 'Kochi', 'Ludhiana', 'Dehradun', 'San Franciscao',
#        'Tangerang', 'Berlin', 'Seattle', 'Riyadh', 'Seoul', 'Bangkok',
#        'Kanpur', 'Chandigarh', 'Warangal', 'Hyderebad', 'Odisha', 'Bihar',
#        'Goa', 'Tamil Nadu', 'Uttar Pradesh', 'Bhopal', 'Banglore',
#        'Coimbatore', 'Bengaluru'], dtype=object)

# %%
#Renaming Some od Headquarter Entries
data20['HeadQuarter'] = data20['HeadQuarter'].str.replace('Banglore','Bengaluru', case=False)

# %%
data20['HeadQuarter'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli', 'Thane', 'Unknown',
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'Delhi', 'Frisco', 'California', 'Dhingsara', 'New York', 'Patna',
#        'San Francisco', 'San Ramon', 'Paris', 'Plano', 'Sydney',
#        'San Francisco Bay Area', 'Bangaldesh', 'London', 'Milano',
#        'Palmwoods', 'France', 'Trivandrum', 'Cochin', 'Samastipur',
#        'Irvine', 'Tumkur', 'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing',
#        'Rajastan', 'Kochi', 'Ludhiana', 'Dehradun', 'San Franciscao',
#        'Tangerang', 'Berlin', 'Seattle', 'Riyadh', 'Seoul', 'Bangkok',
#        'Kanpur', 'Chandigarh', 'Warangal', 'Hyderebad', 'Odisha', 'Bihar',
#        'Goa', 'Tamil Nadu', 'Uttar Pradesh', 'Bhopal', 'Bengaluru',
#        'Coimbatore'], dtype=object)

# %%
data20['Stage'].value_counts(ascending= False)
# Out:
# Series A                 555
# Seed                      79
# Seed Round                69
# Series B                  57
# Pre series A              54
# Pre-series A              53
# Series C                  50
# Series D                  22
# Debt                      18
# Pre Series A              12
# Pre-seed                  11
# Seed round                 9
# Series E                   6
# Bridge                     6
# Series F                   4
# Pre-series B               4
# Angel Round                4
# Pre seed round             4
# Pre-seed Round             2
# Pre series B               2
# Pre-Seed                   2
# Seed Funding               2
# Series B2                  2
# Pre-series C               2
# Seed funding               2
# Pre-Series B               2
# Seed Round & Series A      1
# Series C, D                1
# Mid series                 1
# Series D1                  1
# Seed Investment            1
# Pre series C               1
# Pre-series                 1
# Bridge Round               1
# Series H                   1
# Seed A                     1
# Pre- series A              1
# Series E2                  1
# Pre series A1              1
# Edge                       1
# Pre seed Round             1
# Series A-1                 1
# Name: Stage, dtype: int64

# %%
data20.head()
# Out:
#   Company/Brand              Sector  Amount($)     Stage HeadQuarter
# 0    Aqgromalin            AgriTech  200000.00  Series A     Chennai
# 1      Krayonnz              EdTech  100000.00  Pre-seed   Bangalore
# 2  PadCare Labs  Hygiene management 3000000.00  Pre-seed        Pune
# 3         NCOME              Escrow  400000.00  Series A   New Delhi
# 4    Gramophone            AgriTech  340000.00  Series A      Indore

# %%
# Creating a year column and filling with 2018
data20.insert(0,'Year', 2020)
data20.head()
# Out:
#    Year Company/Brand              Sector  Amount($)     Stage HeadQuarter
# 0  2020    Aqgromalin            AgriTech  200000.00  Series A     Chennai
# 1  2020      Krayonnz              EdTech  100000.00  Pre-seed   Bangalore
# 2  2020  PadCare Labs  Hygiene management 3000000.00  Pre-seed        Pune
# 3  2020         NCOME              Escrow  400000.00  Series A   New Delhi
# 4  2020    Gramophone            AgriTech  340000.00  Series A      Indore

# %% [markdown]
# The Final Cleaned 2020 DataSet

# %%
data20.head()
# Out:
#    Year Company/Brand              Sector  Amount($)     Stage HeadQuarter
# 0  2020    Aqgromalin            AgriTech  200000.00  Series A     Chennai
# 1  2020      Krayonnz              EdTech  100000.00  Pre-seed   Bangalore
# 2  2020  PadCare Labs  Hygiene management 3000000.00  Pre-seed        Pune
# 3  2020         NCOME              Escrow  400000.00  Series A   New Delhi
# 4  2020    Gramophone            AgriTech  340000.00  Series A      Indore

# %% [markdown]
# ## 2.2.4. Cleaning 2021 Dataset

# %%
data21.head(10)
# Out:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics  2019.00   Bangalore      AI startup
# 1          upGrad  2015.00      Mumbai          EdTech
# 2     Lead School  2012.00      Mumbai          EdTech
# 3         Bizongo  2015.00      Mumbai  B2B E-commerce
# 4        FypMoney  2021.00    Gurugram         FinTech
# 5   Urban Company  2014.00   New Delhi   Home services
# 6  Comofi Medtech  2018.00   Bangalore      HealthTech
# 7     Qube Health  2016.00      Mumbai      HealthTech
# 8        Vitra.ai  2020.00   Bangalore    Tech Startup
# 9          Taikee  2010.00      Mumbai      E-commerce
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
# 5  Urban Company (Formerly UrbanClap) is a home a...
# 6   Comofi Medtech is a healthcare robotics startup.
# 7  India's Most Respected Workplace Healthcare Ma...
# 8  Vitra.ai is an AI-based video translation plat...
# 9  Taikee is the ISO-certified, B2B e-commerce pl...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
# 5  Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 6                                         Gururaj KB
# 7                                        Gagan Kapur
# 8                                     Akash Nidhi PS
# 9                 Nidhi Ramachandran, Sachin Chhabra
#
#                                         Investor        Amount         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed
# 5                                     Vy Capital  $188,000,000          None
# 6                              CIIE.CO, KIIT-TBI      $200,000          None
# 7                      Inflection Point Ventures   Undisclosed  Pre-series A
# 8                              Inflexor Ventures   Undisclosed          None
# 9                                           None    $1,000,000          None

# %% [markdown]
# Cleaning data Column Wise

# %%
# Checking for data types
data21.dtypes
# Out:
# Company_Brand     object
# Founded          float64
# HeadQuarter       object
# Sector            object
# What_it_does      object
# Founders          object
# Investor          object
# Amount            object
# Stage             object
# dtype: object

# %% [markdown]
# one column is float, we need to convert amount column to float

# %% [markdown]
# I. DROP COLUMNS NOT NEEDED FOR ANALYSIS, TO MATCH ALL THE DATASETS
# i.e Founder, Founded, What it does and Investor

# %%
data21.columns
# Out:
# Index(['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage'],
#       dtype='object')

# %%
columndrop = ['Founded', 'Founders', 'What_it_does', 'Investor']
data21.drop(columndrop, axis=1, inplace=True)

# %%
data21.head()
# Out:
#     Company_Brand HeadQuarter          Sector        Amount         Stage
# 0  Unbox Robotics   Bangalore      AI startup    $1,200,000  Pre-series A
# 1          upGrad      Mumbai          EdTech  $120,000,000          None
# 2     Lead School      Mumbai          EdTech   $30,000,000      Series D
# 3         Bizongo      Mumbai  B2B E-commerce   $51,000,000      Series C
# 4        FypMoney    Gurugram         FinTech    $2,000,000          Seed

# %%
#rename column names to make it consistent with the other data set
data21.rename(columns={'Company_Brand' : 'Company/Brand'}, inplace = True)
data21.rename(columns= {'Amount': 'Amount($)'}, inplace = True)

# %% [markdown]
# II. Check for duplicates

# %%
#check for duplicates in the data20
duplicates = data21.duplicated(keep=False)

#returns the total number of duplicates
duplicates_count = duplicates.value_counts()
duplicates_count
# Out:
# False    1165
# True       44
# dtype: int64

# %% [markdown]
# We have 44 duplicates in the data 2021

# %%
#identify docuplicated rows
duplicates = data21[data21.duplicated(keep=False)]
duplicates
# Out:
#            Company/Brand             HeadQuarter  \
# 94             Curefoods               Bangalore
# 96              Bewakoof                  Mumbai
# 98               FanPlay          Computer Games
# 104       Advantage Club                  Mumbai
# 106               Ruptok               New Delhi
# 107            Curefoods               Bangalore
# 109             Bewakoof                  Mumbai
# 111              FanPlay          Computer Games
# 117       Advantage Club                  Mumbai
# 119               Ruptok               New Delhi
# 229             Trinkerr               Bangalore
# 230                Zorro                Gurugram
# 231        Ultraviolette               Bangalore
# 232           NephroPlus               Hyderabad
# 233              Unremot               Bangalore
# 234          FanAnywhere               Bangalore
# 235           PingoLearn                    Pune
# 236                 Spry                  Mumbai
# 237              Enmovil               Hyderabad
# 238        ASQI Advisors                  Mumbai
# 239   Insurance Samadhan               New Delhi
# 240      Evenflow Brands                  Mumbai
# 241           MasterChow        Food & Beverages
# 242   Fullife Healthcare  Pharmaceuticals\t#REF!
# 243             Trinkerr               Bangalore
# 244                Zorro                Gurugram
# 245        Ultraviolette               Bangalore
# 246           NephroPlus               Hyderabad
# 247              Unremot               Bangalore
# 248          FanAnywhere               Bangalore
# 249           PingoLearn                    Pune
# 250                 Spry                  Mumbai
# 251              Enmovil               Hyderabad
# 252        ASQI Advisors                  Mumbai
# 253   Insurance Samadhan               New Delhi
# 254      Evenflow Brands                  Mumbai
# 255           MasterChow        Food & Beverages
# 256   Fullife Healthcare  Pharmaceuticals\t#REF!
# 351                Siply               Bangalore
# 401             BharatPe               New Delhi
# 416                Siply               Bangalore
# 847             BharatPe               New Delhi
# 973         Ola Electric               Bangalore
# 1076        Ola Electric               Bangalore
#
#                                                  Sector     Amount($)  \
# 94                                     Food & Beverages     $13000000
# 96                                    Apparel & Fashion      $8000000
# 98                                       Computer Games      Upsparks
# 104                                              HRTech      $1700000
# 106                                             FinTech      $1000000
# 107                                    Food & Beverages     $13000000
# 109                                   Apparel & Fashion      $8000000
# 111                                      Computer Games      Upsparks
# 117                                              HRTech      $1700000
# 119                                             FinTech      $1000000
# 229                                     Capital Markets      $6600000
# 230                                      Social network     $32000000
# 231                                          Automotive    $150000000
# 232                              Hospital & Health Care     $24000000
# 233                   Information Technology & Services       $700000
# 234                                  Financial Services  $Undisclosed
# 235                                          E-learning       $200000
# 236                                               Music      $1500000
# 237                   Information Technology & Services      $1300000
# 238                                  Financial Services      $1000000
# 239                                           Insurance       $725000
# 240                                      Consumer Goods       $500000
# 241                                           Hauz Khas       $461000
# 242   Primary Business is Development and Manufactur...      Series C
# 243                                     Capital Markets      $6600000
# 244                                      Social network     $32000000
# 245                                          Automotive    $150000000
# 246                              Hospital & Health Care     $24000000
# 247                   Information Technology & Services       $700000
# 248                                  Financial Services  $Undisclosed
# 249                                          E-learning       $200000
# 250                                               Music      $1500000
# 251                   Information Technology & Services      $1300000
# 252                                  Financial Services      $1000000
# 253                                           Insurance       $725000
# 254                                      Consumer Goods       $500000
# 255                                           Hauz Khas       $461000
# 256   Primary Business is Development and Manufactur...      Series C
# 351                                             FinTech    $1,000,000
# 401                                             FinTech    $6,000,000
# 416                                             FinTech    $1,000,000
# 847                                             FinTech    $6,000,000
# 973                                          Automotive    $200000000
# 1076                                         Automotive    $200000000
#
#              Stage
# 94            None
# 96            None
# 98        $1200000
# 104           None
# 106           None
# 107           None
# 109           None
# 111       $1200000
# 117           None
# 119           None
# 229       Series A
# 230           Seed
# 231       Series C
# 232       Series E
# 233           Seed
# 234           Seed
# 235           None
# 236           Seed
# 237   Pre-series A
# 238   Pre-series A
# 239   Pre-series A
# 240           None
# 241           Seed
# 242           None
# 243       Series A
# 244           Seed
# 245       Series C
# 246       Series E
# 247           Seed
# 248           Seed
# 249           None
# 250           Seed
# 251   Pre-series A
# 252   Pre-series A
# 253   Pre-series A
# 254           None
# 255           Seed
# 256           None
# 351           Seed
# 401           Debt
# 416           Seed
# 847           Debt
# 973           None
# 1076          None

# %%
#There are 44 duplicated rows
#drop duplicated rows
data21.drop_duplicates(keep='first', inplace= True)

# %%
#check if duplicates have been dropped
duplicates = data21[data21.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Company/Brand, HeadQuarter, Sector, Amount($), Stage]
# Index: []

# %% [markdown]
# All the dupicated rows have been dropped.

# %% [markdown]
# III. Check missing values

# %%
data21.isnull().sum()
# Out:
# Company/Brand      0
# HeadQuarter        1
# Sector             0
# Amount($)          3
# Stage            420
# dtype: int64

# %% [markdown]
# We have one missing value in Headquarter, Amounts - 3 and Stage column have 420. We have to fill the missing values in the each column seperately.

# %% [markdown]
# #### We can see that there are few missing values. But missing values can be represented using '-', let's check

# %%
# Replacing '-' with NaN
data21.replace("—", np.nan, inplace=True)

# Check for missing values
missing_values_data21 = data21.isnull().sum()
missing_values_data21
# Out:
# Company/Brand      0
# HeadQuarter        1
# Sector             0
# Amount($)          3
# Stage            420
# dtype: int64

# %% [markdown]
# Its justified that this are the only missing values

# %%
# Dealing with Missing Values in Headquarter column fill in with unknown
data21['HeadQuarter'] = data20['HeadQuarter'].fillna('Unknown')
data21.head(10)
# Out:
#     Company/Brand HeadQuarter          Sector     Amount($)         Stage
# 0  Unbox Robotics     Chennai      AI startup    $1,200,000  Pre-series A
# 1          upGrad   Bangalore          EdTech  $120,000,000          None
# 2     Lead School        Pune          EdTech   $30,000,000      Series D
# 3         Bizongo   New Delhi  B2B E-commerce   $51,000,000      Series C
# 4        FypMoney      Indore         FinTech    $2,000,000          Seed
# 5   Urban Company   Bangalore   Home services  $188,000,000          None
# 6  Comofi Medtech   Hyderabad      HealthTech      $200,000          None
# 7     Qube Health     Gurgaon      HealthTech   Undisclosed  Pre-series A
# 8        Vitra.ai   Bangalore    Tech Startup   Undisclosed          None
# 9          Taikee        Pune      E-commerce    $1,000,000          None

# %%
data21['HeadQuarter'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Chennai
# 1       Bangalore
# 2            Pune
# 3       New Delhi
# 4          Indore
#           ...
# 1204          NaN
# 1205          NaN
# 1206          NaN
# 1207          NaN
# 1208          NaN
# Name: HeadQuarter, Length: 1187, dtype: object>

# %% [markdown]
# We have NaN in the Headquarter Column. Lets convert the values to strings and check if still have missing values

# %%
data21['HeadQuarter'] = data21['HeadQuarter'].astype(str)

# %%
data21['HeadQuarter'].value_counts()
# Out:
# Bangalore              309
# Mumbai                 160
# nan                    159
# Unknown                 93
# Gurugram                74
#                       ...
# Newcastle Upon Tyne      1
# Shanghai                 1
# Jiaxing                  1
# Rajastan                 1
# Coimbatore               1
# Name: HeadQuarter, Length: 71, dtype: int64

# %%
data21['HeadQuarter'].isna().sum()
# Out:
# 0

# %% [markdown]
# The misisng Values in Headquarter Column has been handled.

# %% [markdown]
# The amount column needs cleaning before filling the missing values with the median value

# %%
# Replacing the missing values in Amount columns with median value
# Replace '$' currency symbol and commas with empty string
data21['Amount($)'] = data21['Amount($)'].str.replace(',', '', regex=False).str.replace('$', '', regex=False)
data21
# Out:
#        Company/Brand HeadQuarter                 Sector  Amount($)  \
# 0     Unbox Robotics     Chennai             AI startup    1200000
# 1             upGrad   Bangalore                 EdTech  120000000
# 2        Lead School        Pune                 EdTech   30000000
# 3            Bizongo   New Delhi         B2B E-commerce   51000000
# 4           FypMoney      Indore                FinTech    2000000
# ...              ...         ...                    ...        ...
# 1204        Gigforce         nan  Staffing & Recruiting    3000000
# 1205          Vahdam         nan       Food & Beverages   20000000
# 1206    Leap Finance         nan     Financial Services   55000000
# 1207    CollegeDekho         nan                 EdTech   26000000
# 1208          WeRize         nan     Financial Services    8000000
#
#              Stage
# 0     Pre-series A
# 1             None
# 2         Series D
# 3         Series C
# 4             Seed
# ...            ...
# 1204  Pre-series A
# 1205      Series D
# 1206      Series C
# 1207      Series B
# 1208      Series A
#
# [1187 rows x 5 columns]

# %%
data21['Amount($)'].value_counts()
# Out:
# Undisclosed    115
# 1000000         82
# 2000000         60
# 3000000         48
# 10000000        43
#               ...
# 67000000         1
# 36000000         1
# Upsparks         1
# 720000           1
# 55000000         1
# Name: Amount($), Length: 207, dtype: int64

# %% [markdown]
# The amount column has non numerical entried. Lets check them.

# %%
# Convert the Amount Column to numeric with errors='coerce'
data21['Amount($)'] = pd.to_numeric(data21['Amount($)'], errors='coerce')
# Convert Amount($) column from object to float datatype
data21['Amount($)'] = data21['Amount($)'].astype(float)

# Check for non-numeric values
non_numeric_values = data21['Amount($)'].isna().sum()

# Print the non-numeric values
print(non_numeric_values)
# Out:
# 150

# %% [markdown]
# The non numeric entries are 150 in number. and have been converted to numeric NaN. Lets check missing values again in the amount column Lets now fill the missing values with the median value.

# %%
data21['Amount($)'].unique()
# Out:
# array([1.20e+06, 1.20e+08, 3.00e+07, 5.10e+07, 2.00e+06, 1.88e+08,
#        2.00e+05,      nan, 1.00e+06, 3.00e+06, 1.00e+05, 7.00e+05,
#        9.00e+06, 4.00e+07, 4.90e+07, 4.00e+05, 3.00e+05, 2.50e+07,
#        1.60e+08, 1.50e+05, 1.80e+06, 5.00e+06, 8.50e+05, 5.30e+07,
#        5.00e+05, 1.10e+06, 6.00e+06, 8.00e+05, 1.00e+07, 2.10e+07,
#        7.50e+06, 2.60e+07, 7.40e+06, 1.50e+06, 6.00e+05, 8.00e+08,
#        1.70e+07, 3.50e+06, 1.50e+07, 2.15e+08, 2.50e+06, 3.50e+08,
#        5.50e+06, 8.30e+07, 1.10e+08, 5.00e+08, 6.50e+07, 1.50e+11,
#        3.00e+08, 2.20e+06, 3.50e+07, 1.40e+08, 4.00e+06, 1.30e+07,
#        9.50e+06, 8.00e+06, 1.20e+07, 1.70e+06, 1.50e+08, 1.00e+08,
#        2.25e+08, 6.70e+06, 1.30e+06, 2.00e+07, 2.50e+05, 5.20e+07,
#        3.80e+06, 1.75e+07, 4.20e+07, 2.30e+06, 7.00e+06, 4.50e+08,
#        2.80e+07, 8.50e+06, 3.70e+07, 3.70e+08, 1.60e+07, 4.40e+07,
#        7.70e+05, 1.25e+08, 5.00e+07, 4.90e+06, 1.45e+08, 2.20e+07,
#        7.00e+07, 6.60e+06, 3.20e+07, 2.40e+07, 7.25e+05, 4.61e+05,
#        9.60e+07, 6.00e+07, 2.66e+08, 4.50e+06, 3.25e+08, 6.50e+06,
#        1.60e+06, 2.25e+05, 8.50e+07, 2.35e+05, 2.60e+05, 2.90e+06,
#        8.60e+07, 1.30e+05, 1.00e+04, 1.11e+08, 2.65e+05, 7.60e+07,
#        7.50e+07, 1.00e+09, 1.80e+07, 3.50e+05, 9.50e+07, 4.10e+06,
#        5.20e+06, 1.40e+06, 2.60e+06, 9.00e+05, 1.10e+07, 2.80e+08,
#        1.43e+07, 8.10e+07, 8.20e+06, 7.20e+05, 3.30e+05, 2.00e+08,
#        3.60e+07, 6.70e+07, 1.02e+07, 2.20e+08, 1.08e+08, 4.50e+05,
#        6.60e+08, 4.50e+07, 3.20e+06, 3.70e+05, 4.80e+07, 3.60e+06,
#        1.92e+08, 1.90e+06, 4.10e+07, 1.44e+08, 2.70e+08, 1.40e+05,
#        2.50e+08, 3.20e+05, 4.80e+06, 3.80e+07, 1.25e+05, 6.40e+07,
#        6.20e+05, 1.25e+06, 4.00e+08, 2.70e+07, 2.34e+08, 4.60e+08,
#        1.35e+07, 5.10e+06, 1.95e+08, 7.30e+06, 6.30e+06, 1.25e+07,
#        1.65e+07, 3.40e+05, 4.30e+07, 3.30e+06, 9.20e+07, 1.35e+08,
#        1.55e+05, 2.10e+06, 8.40e+08, 2.48e+08, 4.30e+06, 5.70e+05,
#        4.70e+06, 2.60e+08, 1.75e+08, 1.90e+07, 8.10e+05, 6.00e+08,
#        9.00e+07, 5.70e+06, 6.75e+06, 7.80e+07, 5.40e+06, 1.15e+08,
#        2.55e+08, 5.70e+08, 5.50e+05, 2.70e+06, 4.20e+06, 3.10e+07,
#        5.40e+05, 1.40e+07, 6.20e+06, 7.50e+05, 2.30e+07, 5.50e+07])

# %%
#Check for misisng values again
data21['Amount($)'].isnull().sum()
# Out:
# 150

# %%
#Calculate the median Values and use that first to fill in the missing values.
median_value = data21['Amount($)'].median()
median_value
# Out:
# 3600000.0

# %%
# Replace NaN values with mean
data21['Amount($)'].fillna(median_amount, inplace=True)

# %%
data21['Amount($)'].isnull().sum()
# Out:
# 0

# %% [markdown]
# The missing values and Non numeric values have been filled with the median value.

# %% [markdown]
# Lets now finalize the last missing value column - Stage. Lets fill this with mode value to avoid skewing the data on address poor data quality

# %%
data21['Stage'].value_counts(ascending= False)
# Out:
# Seed             240
# Pre-series A     154
# Series A         125
# Series B          49
# Pre-seed          47
# Series C          44
# Debt              26
# Series D          21
# Series E          17
# Pre-series B      10
# Series F           6
# Pre-series A1      4
# Pre-series         2
# $300000            2
# Series H           2
# Series G           2
# Bridge             2
# Series A+          1
# Series F2          1
# Series B3          1
# PE                 1
# Series F1          1
# Seed+              1
# Early seed         1
# Series D1          1
# $6000000           1
# $1000000           1
# Seies A            1
# $1200000           1
# Series A2          1
# Series I           1
# Name: Stage, dtype: int64

# %%
# Calculate the mode value for the 'Stage' column
mode_stage21 = data21['Stage'].mode().iloc[0]

# Fill the missing values in the 'Stage' column with the mode value
data21['Stage'].fillna(mode_stage21, inplace=True)
data21['Stage']
# Out:
# 0       Pre-series A
# 1               Seed
# 2           Series D
# 3           Series C
# 4               Seed
#             ...
# 1204    Pre-series A
# 1205        Series D
# 1206        Series C
# 1207        Series B
# 1208        Series A
# Name: Stage, Length: 1187, dtype: object

# %%
# lets check if all missing values have been handled.
data21.isnull().sum()
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# Stage            0
# dtype: int64

# %% [markdown]
# All missing values has been handled. Lets Inspect each column for anomaly or entries that need correction

# %% [markdown]
# IV. Inspecting Individual Columns for anomaly

# %%
#Inspecting Company/Brand Column for anomaly
data21['Company/Brand'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1187 entries, 0 to 1208
# Series name: Company/Brand
# Non-Null Count  Dtype
# --------------  -----
# 1187 non-null   object
# dtypes: object(1)
# memory usage: 18.5+ KB

# %% [markdown]
# Company/Brand" Series contains 1187 non-null string values and has a data type of "object.This fine

# %%
#Inspecting Headquarter column
data21['HeadQuarter'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli', 'Thane', 'Unknown',
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'nan', 'Delhi', 'Frisco', 'California', 'Dhingsara', 'New York',
#        'Patna', 'San Francisco', 'San Ramon', 'Paris', 'Plano', 'Sydney',
#        'San Francisco Bay Area', 'London', 'Milano', 'Palmwoods',
#        'France', 'Trivandrum', 'Cochin', 'Samastipur', 'Irvine', 'Tumkur',
#        'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'Tangerang', 'Berlin',
#        'Seattle', 'Riyadh', 'Seoul', 'Bangkok', 'Kanpur', 'Chandigarh',
#        'Warangal', 'Hyderebad', 'Odisha', 'Bihar', 'Goa', 'Tamil Nadu',
#        'Uttar Pradesh', 'Bhopal', 'Bengaluru', 'Coimbatore'], dtype=object)

# %% [markdown]
# we see we have nan and unknown in the column. Lets have uniformity we have the one entry - unknown. lets rename nan to unknown. Also bangalore city to Bengaluru. Now lets check again the anomaly

# %%
data21['HeadQuarter'] = data21['HeadQuarter'].str.replace('Bangalore','Bengaluru', case=False)
data21['HeadQuarter'] = data21['HeadQuarter'].str.replace('nan','Unknown', case=False)

# %%
data21['HeadQuarter'].unique()
# Out:
# array(['Chennai', 'Bengaluru', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli', 'Thane', 'Unknown',
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'Delhi', 'Frisco', 'California', 'Dhingsara', 'New York', 'Patna',
#        'San Francisco', 'San Ramon', 'Paris', 'Plano', 'Sydney',
#        'San Francisco Bay Area', 'London', 'Milano', 'Palmwoods',
#        'France', 'Trivandrum', 'Cochin', 'Samastipur', 'Irvine', 'Tumkur',
#        'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'Tangerang', 'Berlin',
#        'Seattle', 'Riyadh', 'Seoul', 'Bangkok', 'Kanpur', 'Chandigarh',
#        'Warangal', 'Hyderebad', 'Odisha', 'Bihar', 'Goa', 'Tamil Nadu',
#        'Uttar Pradesh', 'Bhopal', 'Coimbatore'], dtype=object)

# %%
data21['HeadQuarter'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1187 entries, 0 to 1208
# Series name: HeadQuarter
# Non-Null Count  Dtype
# --------------  -----
# 1187 non-null   object
# dtypes: object(1)
# memory usage: 18.5+ KB

# %% [markdown]
# The nan and Unknown and correct bengaluru city has been handled

# %%
# 3. inpescting the amount column
data21['Amount($)'].unique()
# Out:
# array([1.20e+06, 1.20e+08, 3.00e+07, 5.10e+07, 2.00e+06, 1.88e+08,
#        2.00e+05, 6.00e+06, 1.00e+06, 3.00e+06, 1.00e+05, 7.00e+05,
#        9.00e+06, 4.00e+07, 4.90e+07, 4.00e+05, 3.00e+05, 2.50e+07,
#        1.60e+08, 1.50e+05, 1.80e+06, 5.00e+06, 8.50e+05, 5.30e+07,
#        5.00e+05, 1.10e+06, 8.00e+05, 1.00e+07, 2.10e+07, 7.50e+06,
#        2.60e+07, 7.40e+06, 1.50e+06, 6.00e+05, 8.00e+08, 1.70e+07,
#        3.50e+06, 1.50e+07, 2.15e+08, 2.50e+06, 3.50e+08, 5.50e+06,
#        8.30e+07, 1.10e+08, 5.00e+08, 6.50e+07, 1.50e+11, 3.00e+08,
#        2.20e+06, 3.50e+07, 1.40e+08, 4.00e+06, 1.30e+07, 9.50e+06,
#        8.00e+06, 1.20e+07, 1.70e+06, 1.50e+08, 1.00e+08, 2.25e+08,
#        6.70e+06, 1.30e+06, 2.00e+07, 2.50e+05, 5.20e+07, 3.80e+06,
#        1.75e+07, 4.20e+07, 2.30e+06, 7.00e+06, 4.50e+08, 2.80e+07,
#        8.50e+06, 3.70e+07, 3.70e+08, 1.60e+07, 4.40e+07, 7.70e+05,
#        1.25e+08, 5.00e+07, 4.90e+06, 1.45e+08, 2.20e+07, 7.00e+07,
#        6.60e+06, 3.20e+07, 2.40e+07, 7.25e+05, 4.61e+05, 9.60e+07,
#        6.00e+07, 2.66e+08, 4.50e+06, 3.25e+08, 6.50e+06, 1.60e+06,
#        2.25e+05, 8.50e+07, 2.35e+05, 2.60e+05, 2.90e+06, 8.60e+07,
#        1.30e+05, 1.00e+04, 1.11e+08, 2.65e+05, 7.60e+07, 7.50e+07,
#        1.00e+09, 1.80e+07, 3.50e+05, 9.50e+07, 4.10e+06, 5.20e+06,
#        1.40e+06, 2.60e+06, 9.00e+05, 1.10e+07, 2.80e+08, 1.43e+07,
#        8.10e+07, 8.20e+06, 7.20e+05, 3.30e+05, 2.00e+08, 3.60e+07,
#        6.70e+07, 1.02e+07, 2.20e+08, 1.08e+08, 4.50e+05, 6.60e+08,
#        4.50e+07, 3.20e+06, 3.70e+05, 4.80e+07, 3.60e+06, 1.92e+08,
#        1.90e+06, 4.10e+07, 1.44e+08, 2.70e+08, 1.40e+05, 2.50e+08,
#        3.20e+05, 4.80e+06, 3.80e+07, 1.25e+05, 6.40e+07, 6.20e+05,
#        1.25e+06, 4.00e+08, 2.70e+07, 2.34e+08, 4.60e+08, 1.35e+07,
#        5.10e+06, 1.95e+08, 7.30e+06, 6.30e+06, 1.25e+07, 1.65e+07,
#        3.40e+05, 4.30e+07, 3.30e+06, 9.20e+07, 1.35e+08, 1.55e+05,
#        2.10e+06, 8.40e+08, 2.48e+08, 4.30e+06, 5.70e+05, 4.70e+06,
#        2.60e+08, 1.75e+08, 1.90e+07, 8.10e+05, 6.00e+08, 9.00e+07,
#        5.70e+06, 6.75e+06, 7.80e+07, 5.40e+06, 1.15e+08, 2.55e+08,
#        5.70e+08, 5.50e+05, 2.70e+06, 4.20e+06, 3.10e+07, 5.40e+05,
#        1.40e+07, 6.20e+06, 7.50e+05, 2.30e+07, 5.50e+07])

# %%
data21['Amount($)'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1187 entries, 0 to 1208
# Series name: Amount($)
# Non-Null Count  Dtype
# --------------  -----
# 1187 non-null   float64
# dtypes: float64(1)
# memory usage: 18.5 KB

# %% [markdown]
# The amount column contains numeric values presented as floats and have 1187 entries no missing values

# %%
# 4. inspecting sector column
data21['Sector'].unique()
# Out:
# array(['AI startup', 'EdTech', 'B2B E-commerce', 'FinTech',
#        'Home services', 'HealthTech', 'Tech Startup', 'E-commerce',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Food & Beverages', 'Aeorspace', 'Deep Tech',
#        'Dating', 'Gaming', 'Robotics', 'Retail', 'Food', 'Oil and Energy',
#        'AgriTech', 'Telecommuncation', 'Milk startup', 'AI Chatbot', 'IT',
#        'Logistics', 'Hospitality', 'Fashion', 'Marketing',
#        'Transportation', 'LegalTech', 'Food delivery', 'Automotive',
#        'SaaS startup', 'Fantasy sports', 'Video communication',
#        'Social Media', 'Skill development', 'Rental', 'Recruitment',
#        'HealthCare', 'Sports', 'Computer Games', 'Consumer Goods',
#        'Information Technology', 'Apparel & Fashion',
#        'Logistics & Supply Chain', 'Healthtech', 'Healthcare',
#        'SportsTech', 'HRTech', 'Wine & Spirits',
#        'Mechanical & Industrial Engineering', 'Spiritual',
#        'Financial Services', 'Industrial Automation', 'Health',
#        'Lifestyle', 'IoT', 'Banking', 'Computer software', 'Tech startup',
#        'Digital mortgage', 'Information Technology & Services',
#        'Furniture', 'B2B marketplace', 'Healtcare', 'Location Analytics',
#        'Media', 'Consumer Electronics', 'Tobacco', 'Deeptech',
#        'Insuretech', 'MLOps platform', 'Venture Capital', 'Pet care',
#        'Drone', 'Wholesale', 'Construction', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Insurance', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Music', 'Hauz Khas',
#        'Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.',
#        "MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.",
#        'Cosmetics', 'Mobility', 'Social media', 'Real Estate',
#        'Digital platform', 'B2B Ecommerce', 'Online Media',
#        'Social commerce', 'Mobile Games', 'Food Production', 'Podcast',
#        'HeathTech', 'Battery', 'Content publishing', 'Water purification',
#        'Content commerce', 'Innovation Management', 'Software company',
#        'Automation', 'Food Industry', 'Celebrity Engagement',
#        'Trading platform', 'Personal Care', 'Cannabis startup',
#        'Blogging', 'Consulting', 'BioTechnology', 'B2B Marketplace',
#        'Health care', 'Social audio', 'Fashion and lifestyle',
#        'Delivery service', 'B2B Manufacturing', 'Home Decor', 'Solar',
#        'TaaS startup', 'EV startup', 'HR Tech', 'Blockchain startup',
#        'Food and Beverages', 'Beverages', 'Manufacturing startup',
#        'Cryptocurrency', 'Vehicle repair startup', 'Advisory firm',
#        'Legaltech', 'Pollution control equiptment', 'Fashion & Lifestyle',
#        'Blockchain', 'Fitness', 'D2C', 'Automobile',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Biotechnology', 'Farming', 'NFT Marketplace',
#        'Internet', 'SpaceTech', 'Consumer software', 'Social community',
#        'Fishery', 'Renewables & Environment', 'Online storytelling',
#        'Aviation', 'IT company', 'Environmental service',
#        'Job discovery platform', 'D2C Fashion', 'Heathcare', 'CRM',
#        'Software', 'Nutrition', 'D2C startup', 'Innovation management',
#        'Community platform', 'Venture capitalist', 'Networking',
#        'Commercial Real Estate', 'AR startup', 'Consumer service',
#        'Consumer goods', 'MarTech', 'Advertisement', 'Content creation',
#        'Augmented reality', 'Rental space', 'Bike Rental',
#        'Beauty products', 'Tourism', 'FemTech', 'Cultural', 'Co-working',
#        'InsureTech', 'Supply chain platform', 'Social platform',
#        'CleanTech', 'Real estate', 'AI company', 'Sports startup',
#        'Matrimony', 'Crypto', 'Clothing', 'Analytics', 'Finance',
#        'IoT platform', 'Commerce', 'Defense & Space', 'Entertainment',
#        'Business Supplies & Equipment', 'NFT', 'Oil & Energy', 'EV',
#        'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education', 'B2B',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'SaaS', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Education',
#        'Management Consulting', 'B2B startup',
#        'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience',
#        'Design', 'B2B Travel', 'Interior Design',
#        'Manchester, Greater Manchester', 'Product studio',
#        'Aviation & Aerospace', 'Staffing & Recruiting'], dtype=object)

# %%
data21['Sector'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1187 entries, 0 to 1208
# Series name: Sector
# Non-Null Count  Dtype
# --------------  -----
# 1187 non-null   object
# dtypes: object(1)
# memory usage: 18.5+ KB

# %% [markdown]
# The sector column has all 1187 entries and data type is object

# %%
# 5. Inpecting the stage column
data21['Stage'].unique()
# Out:
# array(['Pre-series A', 'Seed', 'Series D', 'Series C', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        '$1200000', 'Bridge', 'Seed+', 'Series F2', 'Series A+',
#        'Series G', 'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', '$300000', 'Early seed', 'Series D1', '$6000000',
#        '$1000000', 'Seies A', 'Pre-series', 'Series A2', 'Series I'],
#       dtype=object)

# %% [markdown]
# As we can see we have some columns with numbers as objects, lets rename those to unavailable

# %%
data21['Stage'] = data21['Stage'].str.replace('$1200000','Unvailable', case=False)
data21['Stage'] = data21['Stage'].str.replace('$300000','Unavailable', case=False)
data21['Stage'] = data21['Stage'].str.replace('$1000000','Unavailable', case=False)
data21['Stage'] = data21['Stage'].str.replace('$6000000','Unavailable', case=False)

# %%
data21['Stage'].unique()
# Out:
# array(['Pre-series A', 'Seed', 'Series D', 'Series C', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        '$1200000', 'Bridge', 'Seed+', 'Series F2', 'Series A+',
#        'Series G', 'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', '$300000', 'Early seed', 'Series D1', '$6000000',
#        '$1000000', 'Seies A', 'Pre-series', 'Series A2', 'Series I'],
#       dtype=object)

# %% [markdown]
# Stage column anomalies has been fixed. Lets now add the year column and finalize 2021 data clean up

# %%
# Creating a year column and filling with 2018
data21.insert(0,'Year', 2021)
data21.head()
# Out:
#    Year   Company/Brand HeadQuarter          Sector    Amount($)         Stage
# 0  2021  Unbox Robotics     Chennai      AI startup   1200000.00  Pre-series A
# 1  2021          upGrad   Bengaluru          EdTech 120000000.00          Seed
# 2  2021     Lead School        Pune          EdTech  30000000.00      Series D
# 3  2021         Bizongo   New Delhi  B2B E-commerce  51000000.00      Series C
# 4  2021        FypMoney      Indore         FinTech   2000000.00          Seed

# %%
#Lets arrange the columns to the match the other datasets
# Create a list of column names in the desired order
desired_columns = ['Year', 'Company/Brand', 'Sector', 'Amount($)', 'Stage', 'HeadQuarter']

# Reindex the DataFrame with the desired column order
data21 = data21.reindex(columns=desired_columns)

data21.head()
# Out:
#    Year   Company/Brand          Sector    Amount($)         Stage HeadQuarter
# 0  2021  Unbox Robotics      AI startup   1200000.00  Pre-series A     Chennai
# 1  2021          upGrad          EdTech 120000000.00          Seed   Bengaluru
# 2  2021     Lead School          EdTech  30000000.00      Series D        Pune
# 3  2021         Bizongo  B2B E-commerce  51000000.00      Series C   New Delhi
# 4  2021        FypMoney         FinTech   2000000.00          Seed      Indore

# %% [markdown]
# We now all the 4 datasets cleaned now lets concat them for further analysis

# %% [markdown]
# ## 2.3.DATA CONCATENATING
# Concat the datasets together to have the one start up data set

# %%
# Create a list of the datasets
datasets = [data18, data19, data20, data21]

# Concatenate the datasets vertically
final_data = pd.concat(datasets, ignore_index=True)

# %% [markdown]
# Lets check if the final data has duplicates and missing values before we prepare the data for analysis by adding new features

# %%
# Checking for duplicates.
duplicates = final_data[final_data.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Year, Company/Brand, Sector, Stage, Amount($), HeadQuarter]
# Index: []

# %%
#There are 44 duplicated rows
#drop duplicated rows
final_data.drop_duplicates(keep='first', inplace= True)

# %%
# Lets check if the duplicates were removed.
duplicates = final_data[final_data.duplicated(keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Year, Company/Brand, Sector, Stage, Amount($), HeadQuarter]
# Index: []

# %% [markdown]
# The duplicated rows has been dropped. Lets check for missing values.

# %%
final_data.isnull().sum()
# Out:
# Year             0
# Company/Brand    0
# Sector           0
# Stage            0
# Amount($)        0
# HeadQuarter      0
# dtype: int64

# %% [markdown]
# There are no missing values. Lets check unique values for each column

# %%
print(final_data['Sector'].unique().tolist())
# Out:
# ['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing', 'Agriculture, Farming', 'Credit, Financial Services, Lending, Marketplace', 'Financial Services, FinTech', 'E-Commerce Platforms, Retail, SaaS', 'Cloud Infrastructure, PaaS, SaaS', 'Internet, Leisure, Marketplace', 'Market Research', 'Information Services, Information Technology', 'Mobile Payments', 'B2B, Shoes', 'Internet', 'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat', 'Food Delivery', 'Industrial Automation', 'Automotive, Search Engine, Service Industry', 'Finance, Internet, Travel', 'Accounting, Business Information Systems, Business Travel, Finance, SaaS', 'Artificial Intelligence, Product Search, SaaS, Service Industry, Software', 'Internet of Things, Waste Management', 'Air Transportation, Freight Service, Logistics, Marine Transportation', 'Financial Services', 'Food and Beverage', 'Autonomous Vehicles', 'Enterprise Software, Health Care, Hospital, Parenting, Personal Health, SaaS', 'Agriculture, Analytics, Big Data, Farming', 'Logistics, Supply Chain Management', 'Financial Services, Lending', 'Automotive, Marketplace, Online Portals', 'Artificial Intelligence', 'Internet of Things, Telecommunications', 'Insurance', 'Information Technology, Logistics, Supply Chain Management', 'Blockchain, Developer Tools, Enterprise Software', 'Industrial Automation, Logistics, Supply Chain Management', 'Food and Beverage, Food Delivery, Snack Food', 'Education', 'E-Commerce, Fashion, Jewelry, Retail', 'Renewable Energy', 'E-Learning, Education', 'Clean Energy, CleanTech, Laundry and Dry-cleaning', 'E-Commerce, Fashion, Mobile', 'Apps, Messaging, Navigation, Public Safety', 'Transportation', 'Fitness, Health Care, Wellness', 'Artificial Intelligence, Machine Learning, SaaS, Virtual Assistant', 'Hospitality', 'Food and Beverage, Tea', 'Media and Entertainment, News, Outdoors', 'Broadcasting, Media and Entertainment, Music, Music Streaming, Video, Video Streaming', 'B2B, Information Services, Information Technology', 'EdTech, Education, Enterprise Software, Peer to Peer', 'Health Care, Medical', 'E-Commerce', 'Health Care, Hospital, Wellness', 'Unknown', 'Sports', 'Big Data, Consumer Lending, FinTech', 'Cloud Computing, Computer, Semiconductor', 'Health Care, Medical, Pharmaceutical', 'Food Processing, Retail', 'Trading Platform', "Consumer Goods, Lifestyle, Men's", 'Wellness', 'Food and Beverage, Food Processing, Nutrition', 'Fashion', 'Automotive, Electric Vehicle, Energy Storage', 'Consulting, Retail, Social', 'Biotechnology, Life Science, Pharmaceutical, Product Research', 'Health Care', 'Credit, Financial Services, FinTech, Personal Finance', 'Communities, Coworking, Incubators', 'Consumer, Financial Services, FinTech', 'Consumer Applications, Information Services, Location Based Services, Virtual Assistant', 'Mobile, Mobile Apps, Personalization, Test and Measurement, Web Apps', 'Education, Financial Services, FinTech', 'Advertising, Consulting, Digital Marketing', 'Marketplace, Real Estate, Rental Property', 'E-Learning, Internet, Video Games', 'Artificial Intelligence, Cloud Computing, Video', 'Health Care, Information Technology', 'Aerospace', 'E-Commerce, Fashion, Lifestyle', 'Artificial Intelligence, Business Intelligence, Industrial Automation, Machine Learning', 'Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home', 'EdTech, Education, Information Services, SaaS', 'Energy, Solar', 'B2B, Biometrics, Cyber Security, Fraud Detection, SaaS, Security', 'Artificial Intelligence, Social', 'Logistics, Transportation, Travel', 'Digital Marketing, SEM, SEO, Web Development', 'Health Care, Hospital, Medical', 'Finance, Financial Services', 'Food Delivery, Food Processing, Internet', 'E-Commerce, Food and Beverage, Internet', 'Fitness, Food and Beverage, Health Care, Nutrition', 'EdTech, Education, Knowledge Management', 'Apps, Beauty, Consumer, Retail', 'Creative Age ...

# %%
final_data['Company/Brand'].value_counts()
# Out:
# BharatPe                        9
# Zomato                          7
# Vedantu                         6
# Spinny                          6
# Zetwerk                         6
#                                ..
# Reliance Retail Ventures Ltd    1
# Chargebee                       1
# Credit Wise Capital             1
# Uni                             1
# WeRize                          1
# Name: Company/Brand, Length: 2214, dtype: int64

# %%
final_data['HeadQuarter'].unique()
# Out:
# array(['Bengaluru', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad', 'Kalkaji',
#        'Delhi', 'India', 'Hubli', 'New Delhi', 'Chennai', 'Mohali',
#        'Kolkata', 'Pune', 'Jodhpur', 'Kanpur', 'Ahmedabad', 'Azadpur',
#        'Haryana', 'Cochin', 'Faridabad', 'Jaipur', 'Kota', 'Anand',
#        'Bengaluru City', 'Belgaum', 'Thane', 'Margão', 'Indore', 'Alwar',
#        'Kannur', 'Trivandrum', 'Ernakulam', 'Kormangala', 'Uttar Pradesh',
#        'Andheri', 'Mylapore', 'Ghaziabad', 'Kochi', 'Powai', 'Guntur',
#        'Kalpakkam', 'Bhopal', 'Coimbatore', 'Worli', 'Alleppey',
#        'Chandigarh', 'Guindy', 'Lucknow', 'Unknown', 'Telangana',
#        'Bangalore', 'Gurugram', 'Surat', 'Uttar pradesh', 'Rajasthan',
#        'Tirunelveli', 'Singapore', 'Gujarat', 'Kerala', 'Frisco',
#        'California', 'Dhingsara', 'New York', 'Patna', 'San Francisco',
#        'San Ramon', 'Paris', 'Plano', 'Sydney', 'San Francisco Bay Area',
#        'Bangaldesh', 'London', 'Milano', 'Palmwoods', 'France',
#        'Samastipur', 'Irvine', 'Tumkur', 'Newcastle Upon Tyne',
#        'Shanghai', 'Jiaxing', 'Rajastan', 'Ludhiana', 'Dehradun',
#        'San Franciscao', 'Tangerang', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'Bangkok', 'Warangal', 'Hyderebad', 'Odisha', 'Bihar',
#        'Goa', 'Tamil Nadu'], dtype=object)

# %%
final_data['Stage'].value_counts(ascending= False)
# Out:
# Seed              1018
# Series A           809
# Pre-series A       208
# Series B           134
# Series C           113
#                   ...
# Pre seed Round       1
# Pre series A1        1
# Series E2            1
# Bridge Round         1
# Series I             1
# Name: Stage, Length: 74, dtype: int64

# %% [markdown]
# Lets replace the unknown entries with the mode of the final data stage. To avoid data skewed and give bias analysis.

# %%
final_data['Year'].unique()
# Out:
# array([2018, 2019, 2020, 2021], dtype=int64)

# %% [markdown]
# ## 3. DATA PREPARATION
# 3.1 Data engineering adding new features and refining data for modeling
#
# We looking to group our Sector column to following categories:
#
# **Commerce:** *Contain commerce related topics such as brand marketing, business consumer etc*
#
# **Agriculture:** *Containing Farming related terms*
#
# **Finance:** *containing Finance related terms such bank,credit,capital etc*
#
# **Technology:** *containing technology related terms such as AI, tech,portals etc*
#
# **Business Intelligence:** *containing terms such as analytics, human, advertising and other related to business intelligence*
#
# **Food & Beverages:** *Any terms related to food and beverages*
#
# **Transport:** *Any terms related to transport*
#
# **Education:** *Any terms related to education such  edutech, education*
#
# **Beauty & Fashion:** *Any terms related to beauty and fashion industry*
#
# **Energy:** *Any terms associated with energy sector*
#
# **Lifestyle:** *Any terms related to sector lifestyle*
#
# **Hospitality:** *Any terms related to hospitality such tourism, events etc*
#
# **Health:** *Any health related terms*
#
# **Sports:** *Any terms associated with sports*
#
# **Media & Entertainment:** *Any terms asscoiated with Media industry*
#
# **Manufacturing:** *Any terms associated to manufacturing industry*
#
# **Telecommunications:** *Terms associated with telecommunications industry*

# %%
# Remodelling Sector column
#regex grouping convert
final_data['Sector'] = final_data['Sector'].str.lower()
final_data['Sector'] =final_data['Sector'].apply(lambda x: 'business consumer' if x == 'consumer' else x)
final_data['Sector'] =final_data['Sector'].apply(lambda x: 'e-vehicle' if x == 'ev' else x)
final_data['Sector'] =final_data['Sector'].apply(lambda x: 'tech' if x == 'it' else x)

# %%
# Function for redefining the sector column.
def sector_redistribution(sector):
    if re.search(r'artificial intelligence|tech|cloud|artificial|data|internet|things|apps|android|software|'
                   r'portals|fraud detection|search engine|nanotechnology|security|saas|\bit company\b|'
                   r'computer|mobile|3d printing|funding platform|applications|file|embedded systems|'
                   r'augmented reality|drones|ar startup|]\baas\b|app|/|virtual|it startup|'
                   r'photonics|e tailor|\bai\b|ai & debt|ai company|ai chatbot|iot startup|\biot\b|'
                   r'\bsocial platform\b|\bar platform\b|\bapi platform\b|\bmlops platform\b|online storytelling|'
                   r'\bdigital platform\b|paas startup|taas startup|digital assistant', sector):
        return 'Technology'
    elif re.search(r'bank|fintech|finance|cryto|account|credit|venture|crowd|blockchain|fund|lending|financial|'
                 r'trading|wealth|insurance|remittance|money|wealth|equity|investment|mortage|financial services|'
                 r'nft|payments', sector):
        return 'Finance'
    elif re.search(r'automotive|air transport|transport|logistics|vehicle|transportation|'
                   r'aviation|vehicles|tyre|fleet|aer|mobility|aerospace|wl & rac protection|'
                   r'micro-mobility|delivery service', sector):
        return 'Transport'
    elif re.search(r'clean energy|boil &|\boil\b|energy|electricity|solar|environment', sector):
        return 'Energy'
    elif re.search(r'analytics|consulting|career|human|\berp\b|advertising|market research|advertisement|'
                   r'entrepre|recruit|\bhr\b|working|sultancy|work|job|advisory|management|legal|skill|'
                   r'crm|specific doman to individuals|information services', sector):
        return 'Business Intelligence'
    elif re.search(r'decor|fitness|training|wellness|design|personal care|craft|podcas|'
                   r'lifestyle|matrimony|spiritual|living|cultural|home', sector):
        return 'Lifestyle'
    elif re.search(r'cosmetics|beauty|skincare|fashion|wear|cosmetic|textiles|eyewear|cloth|jewellery|eyeglasses', sector):
        return 'Beauty & Fashion'
    elif re.search(r'sports|esports|game|ball|player|manchester', sector):
        return 'Sports'
    elif re.search(r'edutech|education|learn|edtech', sector):
        return 'Education'
    elif re.search(r'beverages|cook|food|restaurants|catering', sector):
        return 'Food & Beverages'
    elif re.search(r'tourism|events|customer|hospital|wedding|travel|hosts|booking|weedding|qsr', sector):
        return 'Hospitality'
    elif re.search(r'2|trade|commerce|enterprise|consumer goods|commercial|business|Marketplace|'
                   r'business consumer|market|marketing|retail|store|wholesale|furniture|wine & spirits|'
                   r'multinational|e-|sales|tplace|packaging|warehouse|fm|product|merchandise|retail|'
                   r'conglomerates|invoice discounting|supply chain|car service|service industry|'
                   r'company-as-a-service|consumer service|facilities support services|facilities services', sector):
        return 'Commerce'
    elif re.search(r'health care|hospital|parenting|personal health|biotechnology|pharmaceutical', sector):
        return 'Health'
    elif re.search(r'agriculture|farming|', sector):
        return 'Agriculture'
    elif re.search(r'telecommunications', sector):
        return 'Telecommunication'
    elif re.search(r'product|productivity tools|shoes', sector):
        return 'Manufacturing'
    elif re.search(r'new|social news|social media', sector):
        return 'Media & Entertainment'
    else:
        return sector

# Applying the sector_redistribution function to the 'Sector' column
final_data['Sector'] = final_data['Sector'].apply(sector_redistribution)

# %%
final_data['Sector'].unique()
# Out:
# array(['Commerce', 'Agriculture', 'Finance', 'Technology',
#        'Business Intelligence', 'Food & Beverages', 'Transport',
#        'Education', 'Beauty & Fashion', 'Energy', 'Lifestyle',
#        'Hospitality', 'Health', 'Sports'], dtype=object)

# %% [markdown]
# The sector column has been categorized to 14 unique sectors:
# Commerce, Agriculture, Finance, Technology, Business Intelligence, Food & Beverages, Transport,Education,Beauty & Fashion, Energy, Lifestyle, Hospitality, Health, Sports

# %% [markdown]
# Lets Model now the Stage Column
# We are looking to get the following Funding stages:
# |Funding Stage | Description |
# |------------- |------------- |
# |Angel Stage | Every Stage that contains Angel |
# |Pre-Seed Stage | Any stage that contains pre-seed,early and non-equity assistance |
# |Seed Stage | Any stage that contains a digit Seed |
# |Pre-Series Stage | Refers to the stage between seed round and series A |
# |Series A Stage | Series A and preseries B |
# |Series B Stage | Series B and pre series C |
# |Series C Stage | Series C
# |Later Stage | Any stage that is beyond C and is not in equity or grant |
# |Grant | Grant |
# |Equity | Equity |

# %%
final_data['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed', 'Series D',
#        'Secondary Market', 'Post-IPO Equity', 'Non-equity Assistance',
#        'Funding Round', 'Fresh funding', 'Pre series A', 'Series G',
#        'Post series A', 'Seed funding', 'Seed fund', 'Series F',
#        'Series B+', 'Seed round', 'Pre-series A', 'Pre-seed',
#        'Pre-series', 'Debt', 'Pre-series C', 'Pre-series B', 'Bridge',
#        'Series B2', 'Pre- series A', 'Edge', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-seed Round',
#        'Seed Round & Series A', 'Pre Series A', 'Pre seed Round',
#        'Angel Round', 'Pre series A1', 'Series E2', 'Seed Round',
#        'Bridge Round', 'Pre seed round', 'Pre series B', 'Pre series C',
#        'Seed Investment', 'Series D1', 'Mid series', 'Series C, D',
#        '$1200000', 'Seed+', 'Series F2', 'Series A+', 'Series B3', 'PE',
#        'Series F1', 'Pre-series A1', '$300000', 'Early seed', '$6000000',
#        '$1000000', 'Seies A', 'Series A2', 'Series I'], dtype=object)

# %%
#regex grouping convert and coming up with a function to apply to the stage column for regrouping
final_data['Stage'] = final_data['Stage'].str.lower()

# %%
def group_stages(stage):
    angel_stages = ['angel','angel round']
    seed_stages = ['seed','seed+','seed round','seed a','seed funding','seed fund','seed investment','funding round', 'fresh funding']
    pre_seed_stages = ['non-equity assistance','pre-seed round','pre seed round','pre_seed','early seed','pre-seed']
    pre_series_stages = ['pre-series','bridge','bridge round','pre- series a','pre series a1','pre-series a','pre series a','pre-series a1']
    series_a_stages = ['seed round & series a','series a', 'series a+', 'series a-1', 'series a2','seies a','post series a','pre-series b','pre series b']
    series_b_stages = ['series b', 'series b+', 'series b2', 'series b3','mid series','pre series c','pre-series c']
    series_c_stages = ['series c', 'series c, d']
    later_stage_stages = ['post-ipo equity','series d', 'edge','','series d1', 'series e', 'series e2', 'series f', 'series f1', 'series f2', 'series g', 'series h', 'series i', 'later stage','corporate round','edge']
    grant_stages = ['grant']
    equity_stages = ['private equity','pe', 'secondary market']
    debt_stages = ['debt financing','post-ipo debt','debt']
    unknown_stages = ['venture - series unknown', 'unavailable','unvailable' 'unknown','unknown','unvailable','$300000','$6000000','$1000000','$1200000','undisclosed']

    if any(stage in angel_stages for angel_stage in angel_stages):
        return 'Angel'
    elif any(stage in seed_stages for seed_stage in seed_stages):
        return 'Seed'
    elif any(stage in pre_seed_stages for pre_seed_stage  in pre_seed_stages):
        return 'Pre-Seed'
    elif any(stage in pre_series_stages for pre_series_stage in pre_series_stages):
        return 'Pre-Series'
    elif any(stage in series_a_stages for series_a_stage in series_a_stages):
        return 'Series A'
    elif any(stage in series_b_stages for series_b_stage in series_b_stages):
        return 'Series B'
    elif any(stage in series_c_stages for series_c_stage in series_c_stages):
        return 'Series C'
    elif any(stage in later_stage_stages for later_stage in later_stage_stages):
        return 'Later Stage'
    elif any(stage in grant_stages for grant_stage in grant_stages):
        return 'Grant'
    elif any(stage in equity_stages for equity_stage in equity_stages):
        return 'Equity'
    elif any(stage in debt_stages for debt_stage in debt_stages):
        return 'Debt Financing'
    elif any(stage in unknown_stages for unknown_stage in unknown_stages):
        return 'Unknown'
    else:
        return stage

final_data['Stage'] = final_data['Stage'].apply(group_stages)

# %%
final_data['Stage'].value_counts(ascending= False)
# Out:
# Seed              1108
# Series A           833
# Pre-Series         300
# Series B           142
# Later Stage        115
# Series C           114
# Pre-Seed            75
# Debt Financing      59
# Unknown             45
# Angel               41
# Equity              14
# Grant                4
# Name: Stage, dtype: int64

# %%
# Final Cleaned and feature engineered data
final_data.head()
# Out:
#    Year    Company/Brand       Sector     Stage   Amount($) HeadQuarter
# 0  2018  TheCollegeFever     Commerce      Seed   250000.00   Bengaluru
# 1  2018  Happy Cow Dairy  Agriculture      Seed   480000.00      Mumbai
# 2  2018       MyLoanCare      Finance  Series A   780000.00     Gurgaon
# 3  2018      PayMe India   Technology     Angel  2000000.00       Noida
# 4  2018         Eunimart   Technology      Seed 17030531.59   Hyderabad

# %% [markdown]
# The stage column has been categorized to:
# Angel, Seed,Pre-Series, Series A, Series B, Series C, Later Stage, Equity and Debt Financing

# %% [markdown]
# ## 3.2 EDA ANALYSIS
# Checking correlationship between the variables of the datasets

# %%
# Data overview
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2850 entries, 0 to 2849
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           2850 non-null   int64
#  1   Company/Brand  2850 non-null   object
#  2   Sector         2850 non-null   object
#  3   Stage          2850 non-null   object
#  4   Amount($)      2850 non-null   float64
#  5   HeadQuarter    2850 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 155.9+ KB

# %% [markdown]
# The data set has 4 categorical columns(with object datatype) and 2 numerical columns with data types - int64 and float64
# data dictionary - 6 columns with 2850 rows

# %%
# Describe the data
final_data.describe(include = 'all').T
# Out:
#                 count unique         top  freq        mean           std  \
# Year          2850.00    NaN         NaN   NaN     2020.02          1.09
# Company/Brand    2850   2214    BharatPe     9         NaN           NaN
# Sector           2850     14  Technology  1328         NaN           NaN
# Stage            2850     12        Seed  1108         NaN           NaN
# Amount($)     2850.00    NaN         NaN   NaN 99369125.22 3101192138.11
# HeadQuarter      2850     98   Bengaluru   471         NaN           NaN
#
#                   min        25%        50%         75%             max
# Year          2018.00    2020.00    2020.00     2021.00         2021.00
# Company/Brand     NaN        NaN        NaN         NaN             NaN
# Sector            NaN        NaN        NaN         NaN             NaN
# Stage             NaN        NaN        NaN         NaN             NaN
# Amount($)      720.00 1000000.00 3000000.00 12000000.00 150000000000.00
# HeadQuarter       NaN        NaN        NaN         NaN             NaN

# %% [markdown]
# We see that the top company, sector stage and headquarter are as follows - Bharatpe,Techmology,unknown and Bengaluru. There are alson 2850 entries for the year column.
#
# lets deal with stage  and amount column to check for outliers and trim them.

# %% [markdown]
# # 3.2.1 Univariate Analysis

# %% [markdown]
# Lets check the distribution of the numerical variablles and Categorical variables

# %%
# Distribution of Amount($) column
numerical_variable = final_data['Amount($)']
numerical_variable.describe(include = 'all').T
# Out:
# count           2850.00
# mean        99369125.22
# std       3101192138.11
# min              720.00
# 25%          1000000.00
# 50%          3000000.00
# 75%         12000000.00
# max     150000000000.00
# Name: Amount($), dtype: float64

# %%
# Using a box to vizualize the amount column and check for outliers
median_value = numerical_variable.median()

# Create a box plot

plt.boxplot(numerical_variable)
plt.ylabel('Funding Amount')
plt.title('Box Plot of Funding Amount')
#Format the y-axis labels in Billions
def millions_formatter(x, pos):
    return f'{x / 1e6:.0f}M'

y_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(y_formatter)
# Add a line for the median value
median_value = numerical_variable.median()
plt.axhline(median_value, color='red', linestyle='--', label='Median')
# Calculate Tukey's fences to identify outliers
Q1 = numerical_variable.quantile(0.25)
Q3 = numerical_variable.quantile(0.75)
IQR = Q3 - Q1
lower_fence = Q1 - 1.5 * IQR
upper_fence = Q3 + 1.5 * IQR

# Find outliers
outliers = numerical_variable[(numerical_variable < lower_fence) | (numerical_variable > upper_fence)]

# Print the outliers
print("Outliers:")
print(outliers)

# Display the plot
plt.show()
# Out:
# Outliers:
# 90      742000000.00
# 101    1000000000.00
# 104      35000000.00
# 115      30000000.00
# 116      30000000.00
#             ...
# 2798    100000000.00
# 2810     50000000.00
# 2817     75000000.00
# 2836     76000000.00
# 2847     55000000.00
# Name: Amount($), Length: 361, dtype: float64

# %% [markdown]
# The Amount column have outliers as shown in the box - 361 occurences. We need to trim the outlier s from the dataset as this will affect our analysis later

# %% [markdown]
# ## Trimming Outliers in Amount column

# %%
# Removing outliers in Amount column
final_data = final_data.drop(outliers.index)  # Drop rows containing outliers from the DataFrame
filtered_data = final_data['Amount($)']  # Select only the 'Amount($)' column

# %%
#checking if outliers have been drops
# Create a box plot of the original 'numerical_variable' with outliers
plt.figure(figsize=(8, 6))
plt.boxplot(numerical_variable)
plt.ylabel('Funding Amount')
plt.title('Box Plot of Funding Amount (with Outliers)')
#Format the y-axis labels in Billions
def millions_formatter(x, pos):
    return f'{x / 1e6:.0f}M'

y_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(y_formatter)

plt.show()

# Create a box plot of the 'filtered_data' without outliers
plt.figure(figsize=(8, 6))
plt.boxplot(filtered_data)
plt.ylabel('Funding Amount')
plt.title('Box Plot of Funding Amount (without Outliers)')
plt.gca().yaxis.set_major_formatter(y_formatter)
plt.yticks(range(0, 41000001, 10000000))  # Set y-axis ticks from 0 to 40 million in steps of 10 million
plt.show()

# %% [markdown]
# The outliers in amount column have been dropped.

# %% [markdown]
# Lets explore the categorical columns and see their distribution

# %%
# Describe the distribution of categorical variables
categorical_variables = ['Company/Brand', 'Stage', 'HeadQuarter']

for variable in categorical_variables:
    value_counts = final_data[variable].value_counts()
    max_count = value_counts.max()
    most_distributed_values = value_counts[value_counts == max_count]
    print(f"Variable: {variable}")
    print(most_distributed_values)
    print()
# Out:
# Variable: Company/Brand
# Nykaa    6
# Name: Company/Brand, dtype: int64
#
# Variable: Stage
# Seed    1028
# Name: Stage, dtype: int64
#
# Variable: HeadQuarter
# Bengaluru    408
# Name: HeadQuarter, dtype: int64

# %% [markdown]
# # 3.2.3 BIVARATE ANALYSIS

# %%
# TO TEST THE RELATIONSHIP BETWEEN SECTOR AND FUNDING AMOUNT
# Calculate the average funding amount for each sector
# Calculate the average funding amount for each sector
bi_grouped = final_data.groupby('Sector')['Amount($)'].mean()

# Create a bar chart with the 'tab20' colormap for distinct colors
bi_grouped.plot(kind='bar', colormap='tab20')
plt.xlabel('Sector')
plt.ylabel('Average Funding Amount (Millions)')
plt.title('Average Funding Amount by Sector')

# Format the y-axis labels in Billions
def millions_formatter(x, pos):
    return f'{x / 1e6:.0f}M'

y_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(y_formatter)
plt.yticks(range(0, 41000001, 10000000))  # Set y-axis ticks from 0 to 40 million in steps of 10 million

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Create a box plot
plt.figure()
final_data.boxplot(column='Amount($)', by='Sector')
plt.xlabel('Sector')
plt.ylabel('Funding Amount (Millions)')
plt.title('Funding Amount by Sector')

# Format the y-axis labels in millions
plt.gca().yaxis.set_major_formatter(y_formatter)
plt.yticks(range(0, 41000001, 10000000))  # Set y-axis ticks from 0 to 40 million in steps of 10 million
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# There is a relationship between the sector and funding amount given.

# %% [markdown]
# # 3.2.3. Multivarate Analysis

# %%
#Lets explore the relationship between the funding amount, year and stage

df_sorted = final_data.sort_values('Year')
# Create a scatter plot with different colors for each stage
stages = final_data['Stage'].unique()
colors = ['red', 'green', 'blue', 'orange', 'purple','indigo','lightblue','lightgreen','lightcoral','gray', 'yellow','pink']  # Choose colors for each stage

plt.figure()
for stage, color in zip(stages, colors):
    stage_data = final_data[final_data['Stage'] == stage]
    plt.scatter(stage_data['Year'], stage_data['Amount($)'], color=color, label=stage)
    plt.xticks(final_data['Year'].unique())  # Show all years on the X-axis
# Format the y-axis labels in millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.0f}M'

y_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(y_formatter)

plt.xlabel('Year')
plt.ylabel('Funding Amount')
plt.title('Funding Amount vs. Year by Stage')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()  # Ensures the plot elements do not overlap
plt.show()

# %% [markdown]
# From the Multivariate - there is relationship between type Stage and year when it comes to funding, as shown by the scatter plot. There is variations when it comes funding amount and the funding stage over the years.

# %%
#checking correlation between year and funding amount
correlation_data = final_data[['Year','Amount($)']]

# Compute the correlation matrix
correlation_matrix = correlation_data.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#            Year  Amount($)
# Year       1.00      -0.15
# Amount($) -0.15       1.00

# %% [markdown]
# The correlation coefficient between 'Year' and 'Amount($)' is 0.02, indicating a very weak positive correlation. This suggests that there is little to no linear relationship between the year and funding amount.

# %% [markdown]
# ## GENERATE THE EXCEL DATA to be used in POWERBI Deployment

# %%
file_path = r"C:\Users\PRECIOUS\Desktop\Career Accelerator Phase\LP1_Indian Startup Ecosystem\desired_final.xlsx"

# Export the DataFrame to Excel
final_data.to_excel(file_path, index=False)

print("Excel file generated successfully.")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5760\998351087.py in <module>
#       2
#       3 # Export the DataFrame to Excel
# ----> 4 final_data.to_excel(file_path, index=False)
#       5
#       6 print("Excel file generated successfully.")
#
# c:\Users\PRECIOUS\anaconda\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2343             inf_rep=inf_rep,
#    2344         )
# -> 2345         formatter.write(
#    2346             excel_writer,
#    2347             sheet_name=sheet_name,
#
# c:\Users\PRECIOUS\anaconda\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     886             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888             writer = ExcelWriter(  # type: ignore[abstract]
#     889                 writer, engine=engine, storage_options=storage_options
#     890             )
#
# c:\Users\PRECIOUS\anaconda\lib\site-packages\pandas\io\excel\_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     189             raise ValueError("Append mode is not supported with xlsxwriter!")
#     190
# --> 191         super().__init__(
#     192             path,
#     193             engine=engine,
#
# c:\Users\PRECIOUS\anaconda\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1104         )
#    1105         if not isinstance(path, ExcelWriter):
# -> 1106             self.handles = get_handle(
#    1107                 path, mode, storage_options=storage_options, is_text=False
#    1108             )
#
# c:\Users\PRECIOUS\anaconda\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     793         else:
#     794             # Binary mode
# --> 795             handle = open(handle, ioargs.mode)
#     796         handles.append(handle)
#     797
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\PRECIOUS\\Desktop\\Career Accelerator Phase\\LP1_Indian Startup Ecosystem\\desired_final.xlsx'

# %% [markdown]
# ## 4. ANSWERING THE QUESTIONS

# %% [markdown]
# Qn.1 Which company has the highest funding?

# %%
# Find the company(ies) with the highest funding amount
companies_with_highest_funding = final_data[final_data['Amount($)'] == final_data['Amount($)'].max()]

# Get the company name(s) with the highest funding
top_companies = companies_with_highest_funding['Company/Brand'].values

# Get the highest funding amount
highest_funding = companies_with_highest_funding['Amount($)'].values[0]

# Print information about the company(ies) with the highest funding
print("Company with the highest funding:", top_companies)
print("Funding amount: $", highest_funding)

# Sort the DataFrame by 'Amount($)' column in descending order
final_data_sorted = final_data.sort_values('Amount($)', ascending=False)

# Select the top 10 companies with the highest funding
top_10_companies = final_data_sorted.head(10)

# Create a horizontal bar graph to visualize the top 10 companies
colors = ['red', 'green', 'blue', 'orange', 'purple', 'indigo', 'lightblue', 'lightgreen', 'lightcoral', 'gray']
plt.barh(top_10_companies['Company/Brand'], top_10_companies['Amount($)'], color=colors)
plt.xlabel('Funding Amount (Millions)')
plt.title('Top 10 Companies with Highest Funding')
plt.tight_layout()

# Format the x-axis labels in millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.0f}M'

plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(millions_formatter))
plt.xticks(range(0, 41000001, 10000000))  # Set y-axis ticks from 0 to 40 million in steps of 10 million

plt.show()
# Out:
# Company with the highest funding: ['Vivriti Capital']
# Funding amount: $ 28500000.0

# %% [markdown]
# The top 10 highest funded company over the years is Vivriti Capital, True Balance, Miko, LEAD school, Sustone Eduversity, Eduisfun, Belstar Investment and Finance Private Limited and last on the top 10 is Aye Finance

# %% [markdown]
# lets vizualize the top  company each year

# %%
# Group the data by year and find the top company with the highest funding amount for each year
top_company_each_year = final_data.groupby('Year').apply(lambda x: x.loc[x['Amount($)'].idxmax()])

plt.figure(figsize=(12, 6))

# Create a bar chart with 'tab20' colormap for distinct colors
plt.bar(top_company_each_year['Year'], top_company_each_year['Amount($)'])
plt.xlabel('Year')
plt.ylabel('Funding Amount (Millions)')
plt.title('Company with Highest Funding Amount by Year')

# Set the y-axis labels in millions using the formatter function
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'
y_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(y_formatter)

# Add company names as labels on the bars
for i, row in top_company_each_year.iterrows():
    plt.text(row['Year'], row['Amount($)'], row['Company/Brand'], ha='center', va='bottom')

plt.xticks(final_data['Year'].unique())  # Show all years on the X-axis
plt.yticks(range(0, 41000001, 10000000))  # Set y-axis ticks from 0 to 40 million in steps of 10 million

plt.xticks(rotation=90)
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# Print the top company and funding amount for each year
for year, row in top_company_each_year.iterrows():
    print("Year:", year)
    print("Company:", row['Company/Brand'])
    print("Funding Amount: $", f'{row["Amount($)"] / 1e6:.1f}M')
# Out:
# Year: 2018
# Company: Vivriti Capital
# Funding Amount: $ 28.5M
# Year: 2019
# Company: Eduisfun
# Funding Amount: $ 28.0M
# Year: 2020
# Company: True Balance
# Funding Amount: $ 28.0M
# Year: 2021
# Company: Miko
# Funding Amount: $ 28.0M

# %% [markdown]
# Qn.2 Which sector has the highest funding?

# %%
sector_funding = final_data.groupby('Sector')['Amount($)'].sum().sort_values(ascending=False)

top_sector = sector_funding.index[0]
highest_funding = sector_funding.iloc[0]

print("Sector with the highest funding:", top_sector)
print("Funding amount: $", f'{highest_funding / 1e6:.0f}M')

# Get the top 10 sectors
top_10_sectors = sector_funding.head(10)


# Create a bar chart to visualize the top 10 sectors
colors = ['red', 'green', 'blue', 'orange', 'purple', 'indigo', 'lightblue', 'lightgreen', 'lightcoral', 'gray']
plt.barh(top_10_sectors.index, top_10_sectors.values, color=colors)
plt.xlabel('Total Funding Amount (Millions)')
plt.title('Top 10 Sectors by Funding Amount')

# Format the x-axis labels in millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.0f}M'

x_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().xaxis.set_major_formatter(x_formatter)


plt.tight_layout()
plt.show()
# Out:
# Sector with the highest funding: Technology
# Funding amount: $ 5905M

# %% [markdown]
# lets visualize that per year.

# %%
top_sector_each_year = final_data.groupby('Year').apply(lambda x: x.loc[x['Amount($)'].idxmax()])

plt.figure(figsize=(12, 6))
plt.bar(top_sector_each_year['Year'], top_sector_each_year['Amount($)'])
plt.xlabel('Year')
plt.ylabel('Funding Amount')
plt.title('Sector with Highest Funding Amount by Year')
plt.xticks(rotation=90)



# Add company names as labels on the bars
for i, row in top_company_each_year.iterrows():
    plt.text(row['Year'], row['Amount($)'], row['Sector'], ha='center', va='bottom')

# Set the X-axis ticks and labels
years = [2018, 2019, 2020, 2021]
plt.xticks(years)
# Set the y-axis labels in millions using the formatter function
def millions_formatter(x, pos):
    return f'{x / 1e6:.0f}M'
y_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(y_formatter)
plt.yticks(range(0, 41000001, 10000000))  # Set y-axis ticks from 0 to 40 million in steps of 10 million
plt.xticks(rotation=90)
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# Print the top company and funding amount for each year
for year, row in top_company_each_year.iterrows():
    print("Year:", year)
    print("Sector:", row['Sector'])
    print("Funding Amount: $", f'{row["Amount($)"] / 1e6:.2f}M')
    print()
# Out:
# Year: 2018
# Sector: Finance
# Funding Amount: $ 28.50M
#
# Year: 2019
# Sector: Technology
# Funding Amount: $ 28.00M
#
# Year: 2020
# Sector: Technology
# Funding Amount: $ 28.00M
#
# Year: 2021
# Sector: Agriculture
# Funding Amount: $ 28.00M

# %% [markdown]
# The top sector funded over the years is Technology with Funding amount: $ 5905133607.461538
#
# From the vizualization looking at each search top funded sectors: 2019 and 2020 - technology had the highest funding and 2018- Finance and for 2021 Agriculture sector was most funded.

# %% [markdown]
# Qn. 3 What was total amount of funding received in total and for  each year?

# %%
#lets first check the total funding recieved.
# Calculate the overall total funding received
overall_total_funding = final_data['Amount($)'].sum()

# Print the overall total funding received
print("Overall Total Funding Received: $", f'{overall_total_funding/ 1e6:.0f}M')
# Out:
# Overall Total Funding Received: $ 12923M

# %%
total_funding_yearly = final_data.groupby('Year')['Amount($)'].sum()


print('The total funding each year:$', total_funding_yearly)
# Out:
# The total funding each year:$ Year
# 2018   3570115086.94
# 2019    469033200.00
# 2020   4114047404.00
# 2021   4769726000.00
# Name: Amount($), dtype: float64

# %% [markdown]
# Lets vizualize the results

# %%
total_funding_yearly = final_data.groupby('Year')['Amount($)'].sum()
plt.figure(figsize=(12, 6))
#plt.bar(total_funding_yearly('Year','Amount($)'))
total_funding_yearly.plot(kind = 'bar')
plt.xlabel('Year')
plt.ylabel('Funding Amount($)')
plt.title('Total Funding in each year')
plt.xticks(rotation=90)
# Format the y-axis labels in millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'
y_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(y_formatter)


plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# Print total funding amounts per year
for year, total_amount in total_funding_yearly.items():
    print("Year:", year)
    print("Total Funding Amount: $", f'{total_amount / 1e6:.0f}M')
    print()
# Out:
# Year: 2018
# Total Funding Amount: $ 3570M
#
# Year: 2019
# Total Funding Amount: $ 469M
#
# Year: 2020
# Total Funding Amount: $ 4114M
#
# Year: 2021
# Total Funding Amount: $ 4770M

# %% [markdown]
# From the chart its evident that 2021 had the highest funding of 4769726000.0 dollars, followed by 2020, 2018 and 2019 had the lowest funding of 469033200.0 dollars. the decline from 2018 -2019 and then increase from 2020 to 2021 and change of sector funding are due to covid19 epidemic. For example in 2020 Technology was most funded as vizualized in question 2.

# %% [markdown]
# Qn.4 Which is location recieved most funding?

# %%
location_funding = final_data.groupby('HeadQuarter')['Amount($)'].sum().sort_values(ascending= False)
top_location = location_funding.index[0]
highest_funding = location_funding.iloc[0]

print('The top location is:', top_location)
print('The highest funding for that location is: $',f'{highest_funding / 1e6:.0f}M')

# Select the top 10 locations
top_10_locations = location_funding.head(10)


# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
colors = ['red', 'green', 'blue', 'orange', 'purple', 'indigo', 'lightblue', 'lightgreen', 'lightcoral', 'gray']
plt.barh(top_10_locations.index, top_10_locations.values,color =colors)
plt.xlabel('Funding Amount (Millions $)')
# Format the x-axis labels in millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.0f}M'

x_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().xaxis.set_major_formatter(x_formatter)

plt.title('Top 10 Locations by Funding (in Millions)')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# The top location is: Bengaluru
# The highest funding for that location is: $ 2336M

# %% [markdown]
# Lets vizualize the most funded location per year

# %%
# Find the location with the highest funding amount for each year
most_funded_locations = final_data.loc[final_data.groupby('Year')['Amount($)'].idxmax()]

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(most_funded_locations['Year'], most_funded_locations['Amount($)'])
plt.xlabel('Year')
plt.ylabel('Funding Amount($)')
plt.title('Most Funded Location per Year')
plt.xticks(final_data['Year'].unique())  # Show all years on the X-axis

# Print the amounts for the top locations in each year
for index, row in most_funded_locations.iterrows():
    print(f"Year: {row['Year']}, Location: {row['HeadQuarter']}, Funding Amount: {row['Amount($)'] / 1e6:.2f}M")

    # Add location names as annotations to the bars
for index, row in most_funded_locations.iterrows():
    plt.text(row['Year'], row['Amount($)'], row['HeadQuarter'], ha='center', va='bottom')
    # Format the y-axis labels in millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'
y_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(y_formatter)
plt.yticks(range(0, 41000001, 10000000))  # Set y-axis ticks from 0 to 40 million in steps of 10 million

plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()
# Out:
# Year: 2018, Location: Chennai, Funding Amount: 28.50M
# Year: 2019, Location: Mumbai, Funding Amount: 28.00M
# Year: 2020, Location: Gurugram, Funding Amount: 28.00M
# Year: 2021, Location: Bengaluru, Funding Amount: 28.00M

# %% [markdown]
# Qn.5 At what stage do start up recieve most funding?

# %%
stage_funding = final_data.groupby('Stage')['Amount($)'].sum().sort_values(ascending = False)
top_stage = stage_funding.index[0]
highest_funding_stage = location_funding.iloc[0]
print('The top funded stage is:', top_stage)
print('With funding amount of: $', f'{highest_funding_stage / 1e6:.0f}M')

# Select the top 10 stages
top_10_stages = stage_funding.head(10)

# Plot the horizontal bar chart for the top 10 stages
plt.figure(figsize=(10, 6))
colors = ['red', 'green', 'blue', 'orange', 'purple', 'indigo', 'lightblue', 'lightgreen', 'lightcoral', 'gray']
plt.barh(top_10_stages.index, top_10_stages.values, color =colors)
plt.xlabel('Funding Amount ($)')
plt.ylabel('Stage')
plt.title('Top 10 Funded Stages')
# Format the x-axis labels in millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.0f}M'

x_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().xaxis.set_major_formatter(x_formatter)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# The top funded stage is: Seed
# With funding amount of: $ 2336M

# %% [markdown]
# Lets vizualize most funded stage for each year and use pie chart

# %%
# Group the data by 'Year' and find the most funded stage for each year
most_funded_stage_per_year = final_data.groupby('Year').apply(lambda x: x.nlargest(1, 'Amount($)'))

# Reset the index to include 'Year' as a regular column
most_funded_stage_per_year.reset_index(drop=True, inplace=True)

# Create a bar chart to show the most funded stage for each year
plt.figure(figsize=(10, 6))
plt.bar(most_funded_stage_per_year['Year'], most_funded_stage_per_year['Amount($)'])
plt.xlabel('Year')
plt.ylabel('Funding Amount($)')
plt.title('Most Funded Stage for Each Year')
plt.xticks(final_data['Year'].unique())  # Show all years on the X-axis
plt.xticks(rotation=90)
plt.tight_layout()  # Adjust layout to prevent overlapping labels

# Add the stage of funding as text on the bars
for index, row in most_funded_stage_per_year.iterrows():
    plt.text(row['Year'], row['Amount($)'], row['Stage'], ha='center', va='bottom')

    # Print the stage, year, and funding amount
    print(f"Year: {row['Year']}, Stage: {row['Stage']}, Funding Amount: {row['Amount($)'] / 1e6:.2f}M")

  # Format the y-axis labels in millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'
y_formatter = ticker.FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(y_formatter)
plt.yticks(range(0, 41000001, 10000000))  # Set y-axis ticks from 0 to 40 million in steps of 10 million
   

plt.show()
# Out:
# Year: 2018, Stage: Unknown, Funding Amount: 28.50M
# Year: 2019, Stage: Seed, Funding Amount: 28.00M
# Year: 2020, Stage: Series A, Funding Amount: 28.00M
# Year: 2021, Stage: Seed, Funding Amount: 28.00M

# %% [markdown]
# ## CONCLUSION FROM THE ANALYSIS
#
# 1. **Vivriti Capital** company is the most funded over the years with a total funding amount of **$28.5M**.
#    - In the specific years:
#       - In 2018, Vivriti Capital received the most funding with **$28.5M**.
#       - From 2019, Eduisfun Company was the most funded with **$28.0M**.
#       - In 2020, True Balance was the most funded with **$28.0M**.
#       - In 2021, Miko Company was the most funded, with each year receiving **$28.0M** in funding.
#
# 2. The top location funded across the years is **Bengaluru** with a total funding of **$2336M**.
#    - Across the years:
#       - In 2018, Chennai received a funding amount of **$28.5M**.
#       - From 2019, Mumbai location was the most funded of **$28.0M**..
#       - In 2020, Gurugram location received the highest funding of **$28.0M**..
#       - In 2021, Bengaluru was the most funded location, with each year receiving **$28.0M** funding.
#
# 3. **Overall Total Funding Received: $12923M**
#    - Across the years:
#       - In 2018, India received a total funding of **$3570M**.
#       - In 2019, the total funding amount was **$469M**.
#       - In 2020, the total funding amount was **$4114M**.
#       - In 2021, the total funding amount was **$4770M**.
#
# 4. The most funded sector over the four years is **Technology** with a funding amount of **$5905M**.
#    - Across the years:
#       - In 2019 and 2020, Technology was the most funded sector, with each year receiving **$28.0M** in funding.
#       - In 2021, Agriculture was the most funded sector, with a total funding amount of **$28.0M** for that year.
#       - Lastly, Finance was the most funded in 2018, with a total funding amount of **$28.5M**.
#
# 5. The top funding stage is **Seed** with a total funding amount of: **$2336M**.
#    - Across the years:
#       - In 2018, the Unknown stage had the highest funding with **$28.5M**.
#       - In 2019 and 2021 Seed stage received the highest funding of **$28.0M**.
#       - In 2020, Series A stage was the most funded of **$28.0M**.

# %% [markdown]
# ## INSIGHTS GAINED FROM THE ANALYSIS
# To Santa Fe Organization the following insights will help make informed decisions.
# 1.  In Indian Start-Ups funding Ecosytem there is **changing landscape in the market when it comes to funding**. This clearly shown on the different top funded company each year.
#
#
# 2.  **There is shift in investment focus in India locations over the years.** Bengaluru was the main focus over the years. For the new investors they might want to consider the company location when it comes to investment.
#
#
# 3.  It shows **an increasing trend in funding over the years**, with India receiving a **total funding amount of $12.923 billion over the four-year period.** For the new investors India is a promising investment country.
#
#
# 4.  With a **total investment of $5905 million**, the **technology industry** is the most well-funded in India. Additionally, the data shows which industries received the greatest funding for particular years, illustrating **the shifting trends in industry-specific investments.**
#
#
# 5.  **The Seed stage** received most funds - **$2336 million**. The data demonstrates fluctuations in the most funded stage for different years, showing **shifts in risk tolerance and investment preferences.**
